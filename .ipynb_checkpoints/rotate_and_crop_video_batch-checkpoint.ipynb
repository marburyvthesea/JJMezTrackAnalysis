# %% [markdown]
# # Rotate And Crop Video Batch
#
# Batch-process concatenated behavior camera videos with per-video rotation and crop settings.
#
# Workflow:
# 1. Build a per-video config table.
# 2. Preview rotation only for each video.
# 3. Edit any per-video angles or crop boxes.
# 4. Preview rotation plus crop for each video.
# 5. Run the full batch export.

# %%
from pathlib import Path
import math
import ffmpeg
import pandas as pd
from IPython.display import Image, Markdown, display
from tqdm import tqdm


def probe_video(video_path):
    probe = ffmpeg.probe(str(video_path))
    video_stream = next(stream for stream in probe['streams'] if stream['codec_type'] == 'video')
    width = int(video_stream['width'])
    height = int(video_stream['height'])
    duration = float(video_stream['duration'])
    codec_name = video_stream.get('codec_name', 'Unknown')
    return {
        'width': width,
        'height': height,
        'duration_sec': duration,
        'codec_name': codec_name,
    }


def compute_rotated_canvas(width, height, angle_degrees):
    angle_rad = math.radians(angle_degrees)
    new_width = int(abs(width * math.cos(angle_rad)) + abs(height * math.sin(angle_rad)))
    new_height = int(abs(width * math.sin(angle_rad)) + abs(height * math.cos(angle_rad)))
    return angle_rad, new_width, new_height


def normalize_crop_box(crop_box=None, vertices=None):
    if crop_box is None and vertices is None:
        raise ValueError('Provide either crop_box or vertices.')

    if crop_box is not None:
        return {
            'crop_x': int(crop_box['crop_x']),
            'crop_y': int(crop_box['crop_y']),
            'crop_width': int(crop_box['crop_width']),
            'crop_height': int(crop_box['crop_height']),
        }

    x_coordinates = [v[0] for v in vertices]
    y_coordinates = [v[1] for v in vertices]
    x_min = min(x_coordinates)
    x_max = max(x_coordinates)
    y_min = min(y_coordinates)
    y_max = max(y_coordinates)
    return {
        'crop_x': int(x_min),
        'crop_y': int(y_min),
        'crop_width': int(x_max - x_min),
        'crop_height': int(y_max - y_min),
    }


def clamp_crop_box(crop_box, frame_width, frame_height):
    crop_x = max(0, int(crop_box['crop_x']))
    crop_y = max(0, int(crop_box['crop_y']))
    crop_width = int(crop_box['crop_width'])
    crop_height = int(crop_box['crop_height'])

    if crop_width <= 0 or crop_height <= 0:
        raise ValueError(f'Invalid crop size: {crop_width} x {crop_height}')

    if crop_x + crop_width > frame_width or crop_y + crop_height > frame_height:
        raise ValueError(
            f"Crop box {(crop_x, crop_y, crop_width, crop_height)} exceeds frame bounds {(frame_width, frame_height)}"
        )

    return {
        'crop_x': crop_x,
        'crop_y': crop_y,
        'crop_width': crop_width,
        'crop_height': crop_height,
    }


def build_output_path(input_path, output_dir, suffix):
    return output_dir / f'{input_path.stem}{suffix}.avi'


def build_rotated_output_path(input_path, output_dir):
    return build_output_path(input_path, output_dir, suffix='_rotated')


def build_cropped_output_path(input_path, output_dir):
    return build_output_path(input_path, output_dir, suffix='_rotated_cropped')


def build_video_config_df(input_dir, default_angle_degrees, default_crop_box, pattern='*.mp4'):
    input_dir = Path(input_dir)
    video_files = sorted(input_dir.glob(pattern))
    if not video_files:
        raise FileNotFoundError(f'No files matching {pattern!r} found in {input_dir}')

    rows = []
    for video_path in video_files:
        rows.append({
            'file_name': video_path.name,
            'input_file': str(video_path),
            'angle_degrees': float(default_angle_degrees),
            'crop_x': int(default_crop_box['crop_x']),
            'crop_y': int(default_crop_box['crop_y']),
            'crop_width': int(default_crop_box['crop_width']),
            'crop_height': int(default_crop_box['crop_height']),
            'enabled': True,
        })

    return pd.DataFrame(rows)


def build_rotated_stream(input_path, angle_degrees, preview_time_sec=None):
    info = probe_video(input_path)
    angle_rad, rotated_width, rotated_height = compute_rotated_canvas(
        info['width'], info['height'], angle_degrees
    )

    input_kwargs = {}
    if preview_time_sec is not None:
        input_kwargs['ss'] = max(0, float(preview_time_sec))

    stream = (
        ffmpeg
        .input(str(input_path), **input_kwargs)
        .filter(
            'pad',
            rotated_width,
            rotated_height,
            (rotated_width - info['width']) // 2,
            (rotated_height - info['height']) // 2,
            color='0xFFFFFF'
        )
        .filter('rotate', str(angle_rad))
    )

    transform_info = {
        'duration_sec': info['duration_sec'],
        'input_codec': info['codec_name'],
        'rotated_width': rotated_width,
        'rotated_height': rotated_height,
    }
    return stream, transform_info


def build_rotated_cropped_stream(input_path, angle_degrees, crop_box, preview_time_sec=None):
    stream, info = build_rotated_stream(
        input_path=input_path,
        angle_degrees=angle_degrees,
        preview_time_sec=preview_time_sec,
    )
    crop_box = clamp_crop_box(crop_box, info['rotated_width'], info['rotated_height'])
    stream = stream.filter(
        'crop',
        crop_box['crop_width'],
        crop_box['crop_height'],
        crop_box['crop_x'],
        crop_box['crop_y'],
    )
    info.update(crop_box)
    return stream, info


def render_frame_from_stream(stream, input_name):
    out, err = (
        stream
        .output('pipe:', vframes=1, format='image2', vcodec='png')
        .global_args('-loglevel', 'error')
        .run(capture_stdout=True, capture_stderr=True)
    )
    if not out:
        error_text = err.decode('utf-8', errors='replace').strip()
        raise RuntimeError(error_text or f'Could not render preview frame for {input_name}')
    return out


def preview_rotation_only(config_df, preview_time_fraction=0.5):
    results = []
    enabled_df = config_df.loc[config_df['enabled']].reset_index(drop=True)
    for row in tqdm(enabled_df.itertuples(index=False), total=len(enabled_df), desc='Rotation previews', unit='file'):
        input_path = Path(row.input_file)
        info = probe_video(input_path)
        preview_time_sec = info['duration_sec'] * preview_time_fraction
        stream, transform_info = build_rotated_stream(
            input_path=input_path,
            angle_degrees=row.angle_degrees,
            preview_time_sec=preview_time_sec,
        )
        image_bytes = render_frame_from_stream(stream, input_path.name)

        display(Markdown(
            f"### Rotation preview: {input_path.name}\n"
            f"Angle: `{row.angle_degrees}`  \n"
            f"Preview time: `{preview_time_sec:.2f}s`  \n"
            f"Rotated canvas: `{transform_info['rotated_width']} x {transform_info['rotated_height']}`"
        ))
        display(Image(data=image_bytes))

        results.append({
            'file_name': row.file_name,
            'preview_time_sec': preview_time_sec,
            'angle_degrees': row.angle_degrees,
            'rotated_width': transform_info['rotated_width'],
            'rotated_height': transform_info['rotated_height'],
        })

    return pd.DataFrame(results)


def preview_rotated_and_cropped(config_df, preview_time_fraction=0.5):
    results = []
    enabled_df = config_df.loc[config_df['enabled']].reset_index(drop=True)
    for row in tqdm(enabled_df.itertuples(index=False), total=len(enabled_df), desc='Crop previews', unit='file'):
        input_path = Path(row.input_file)
        info = probe_video(input_path)
        preview_time_sec = info['duration_sec'] * preview_time_fraction
        stream, transform_info = build_rotated_cropped_stream(
            input_path=input_path,
            angle_degrees=row.angle_degrees,
            crop_box={
                'crop_x': row.crop_x,
                'crop_y': row.crop_y,
                'crop_width': row.crop_width,
                'crop_height': row.crop_height,
            },
            preview_time_sec=preview_time_sec,
        )
        image_bytes = render_frame_from_stream(stream, input_path.name)

        display(Markdown(
            f"### Rotation + crop preview: {input_path.name}\n"
            f"Angle: `{row.angle_degrees}`  \n"
            f"Preview time: `{preview_time_sec:.2f}s`  \n"
            f"Crop box: `x={transform_info['crop_x']}, y={transform_info['crop_y']}, w={transform_info['crop_width']}, h={transform_info['crop_height']}`"
        ))
        display(Image(data=image_bytes))

        results.append({
            'file_name': row.file_name,
            'preview_time_sec': preview_time_sec,
            'angle_degrees': row.angle_degrees,
            'crop_x': transform_info['crop_x'],
            'crop_y': transform_info['crop_y'],
            'crop_width': transform_info['crop_width'],
            'crop_height': transform_info['crop_height'],
        })

    return pd.DataFrame(results)


def rotate_video_only(input_path, output_path, angle_degrees, overwrite=False):
    stream, info = build_rotated_stream(
        input_path=input_path,
        angle_degrees=angle_degrees,
    )

    ffmpeg_command = (
        stream
        .output(str(output_path), vcodec='mjpeg', qscale=3)
        .global_args('-progress', 'pipe:1', '-nostats', '-loglevel', 'error')
    )

    process = ffmpeg_command.run_async(
        pipe_stdout=True,
        pipe_stderr=True,
        overwrite_output=overwrite,
    )

    pbar = tqdm(
        total=info['duration_sec'],
        desc=input_path.name,
        unit='s',
        dynamic_ncols=True,
        leave=False,
    )

    for raw_line in process.stdout:
        line = raw_line.decode('utf-8', errors='replace').strip()
        if line.startswith('out_time_ms='):
            out_time_ms = int(line.split('=', 1)[1])
            current_time = out_time_ms / 1_000_000
            pbar.update(max(0, current_time - pbar.n))
        elif line == 'progress=end':
            break

    pbar.close()
    return_code = process.wait()
    stderr_output = process.stderr.read().decode('utf-8', errors='replace').strip()

    if return_code != 0:
        raise RuntimeError(stderr_output or f'ffmpeg failed with exit code {return_code}')

    return {
        'input_file': str(input_path),
        'output_file': str(output_path),
        'duration_sec': info['duration_sec'],
        'input_codec': info['input_codec'],
        'rotated_width': info['rotated_width'],
        'rotated_height': info['rotated_height'],
        'angle_degrees': angle_degrees,
    }


def crop_rotated_video(input_path, output_path, crop_box, overwrite=False):
    info = probe_video(input_path)
    crop_box = clamp_crop_box(crop_box, info['width'], info['height'])

    ffmpeg_command = (
        ffmpeg
        .input(str(input_path))
        .filter(
            'crop',
            crop_box['crop_width'],
            crop_box['crop_height'],
            crop_box['crop_x'],
            crop_box['crop_y'],
        )
        .output(str(output_path), vcodec='mjpeg', qscale=3)
        .global_args('-progress', 'pipe:1', '-nostats', '-loglevel', 'error')
    )

    process = ffmpeg_command.run_async(
        pipe_stdout=True,
        pipe_stderr=True,
        overwrite_output=overwrite,
    )

    pbar = tqdm(
        total=info['duration_sec'],
        desc=input_path.name,
        unit='s',
        dynamic_ncols=True,
        leave=False,
    )

    for raw_line in process.stdout:
        line = raw_line.decode('utf-8', errors='replace').strip()
        if line.startswith('out_time_ms='):
            out_time_ms = int(line.split('=', 1)[1])
            current_time = out_time_ms / 1_000_000
            pbar.update(max(0, current_time - pbar.n))
        elif line == 'progress=end':
            break

    pbar.close()
    return_code = process.wait()
    stderr_output = process.stderr.read().decode('utf-8', errors='replace').strip()

    if return_code != 0:
        raise RuntimeError(stderr_output or f'ffmpeg failed with exit code {return_code}')

    return {
        'input_file': str(input_path),
        'output_file': str(output_path),
        'duration_sec': info['duration_sec'],
        'input_codec': info['codec_name'],
        'crop_x': crop_box['crop_x'],
        'crop_y': crop_box['crop_y'],
        'crop_width': crop_box['crop_width'],
        'crop_height': crop_box['crop_height'],
    }


def batch_rotate_from_config(config_df, rotated_output_dir, overwrite=False):
    rotated_output_dir = Path(rotated_output_dir)
    rotated_output_dir.mkdir(parents=True, exist_ok=True)

    enabled_df = config_df.loc[config_df['enabled']].reset_index(drop=True)
    if enabled_df.empty:
        raise ValueError('No enabled videos found in config_df')

    results = []
    for row in tqdm(enabled_df.itertuples(index=False), total=len(enabled_df), desc='Rotate files', unit='file'):
        input_path = Path(row.input_file)
        output_path = build_rotated_output_path(input_path, rotated_output_dir)

        if output_path.exists() and not overwrite:
            results.append({
                'input_file': str(input_path),
                'output_file': str(output_path),
                'status': 'skipped_existing',
            })
            continue

        try:
            result = rotate_video_only(
                input_path=input_path,
                output_path=output_path,
                angle_degrees=row.angle_degrees,
                overwrite=overwrite,
            )
            result['status'] = 'processed'
            results.append(result)
        except Exception as exc:
            results.append({
                'input_file': str(input_path),
                'output_file': str(output_path),
                'status': 'error',
                'error': str(exc),
            })

    return pd.DataFrame(results)


def batch_crop_from_config(config_df, rotated_output_dir, cropped_output_dir, overwrite=False):
    rotated_output_dir = Path(rotated_output_dir)
    cropped_output_dir = Path(cropped_output_dir)
    cropped_output_dir.mkdir(parents=True, exist_ok=True)

    enabled_df = config_df.loc[config_df['enabled']].reset_index(drop=True)
    if enabled_df.empty:
        raise ValueError('No enabled videos found in config_df')

    results = []
    for row in tqdm(enabled_df.itertuples(index=False), total=len(enabled_df), desc='Crop files', unit='file'):
        original_input_path = Path(row.input_file)
        rotated_input_path = build_rotated_output_path(original_input_path, rotated_output_dir)
        output_path = build_cropped_output_path(original_input_path, cropped_output_dir)

        if not rotated_input_path.exists():
            results.append({
                'input_file': str(original_input_path),
                'rotated_input_file': str(rotated_input_path),
                'output_file': str(output_path),
                'status': 'missing_rotated_input',
            })
            continue

        if output_path.exists() and not overwrite:
            results.append({
                'input_file': str(original_input_path),
                'rotated_input_file': str(rotated_input_path),
                'output_file': str(output_path),
                'status': 'skipped_existing',
            })
            continue

        try:
            result = crop_rotated_video(
                input_path=rotated_input_path,
                output_path=output_path,
                crop_box={
                    'crop_x': row.crop_x,
                    'crop_y': row.crop_y,
                    'crop_width': row.crop_width,
                    'crop_height': row.crop_height,
                },
                overwrite=overwrite,
            )
            result['source_input_file'] = str(original_input_path)
            result['rotated_input_file'] = str(rotated_input_path)
            result['status'] = 'processed'
            results.append(result)
        except Exception as exc:
            results.append({
                'input_file': str(original_input_path),
                'rotated_input_file': str(rotated_input_path),
                'output_file': str(output_path),
                'status': 'error',
                'error': str(exc),
            })

    return pd.DataFrame(results)

# %%
input_dir = Path('/Volumes/fsmresfiles/Basic_Sciences/Phys/ContractorLab/Projects/YZ/Miniscope_data/Miniscope_data/Linear_track/BehavCamConcactenated_388')
rotated_output_dir = input_dir / 'rotated_avi'
cropped_output_dir = input_dir / 'rotated_and_cropped_avi'

Bx = 48
By = 377
Width = 668
Height = 36

default_angle_to_rotate = 29.5
default_crop_box = normalize_crop_box(vertices=[(Bx, By), (Bx+Width, By), (Bx+Width, By+Height), (Bx, By+Height)])
preview_time_fraction = 0.5
overwrite_existing = False

video_config_df = build_video_config_df(
    input_dir=input_dir,
    default_angle_degrees=default_angle_to_rotate,
    default_crop_box=default_crop_box,
    pattern='*.mp4',
)

print(f'Found {len(video_config_df)} input videos in {input_dir}')
print(f'Rotated output directory: {rotated_output_dir}')
print(f'Cropped output directory: {cropped_output_dir}')
video_config_df
# Out:
# Found 13 input videos in /Volumes/fsmresfiles/Basic_Sciences/Phys/ContractorLab/Projects/YZ/Miniscope_data/Miniscope_data/Linear_track/BehavCamConcactenated_388
# Rotated output directory: /Volumes/fsmresfiles/Basic_Sciences/Phys/ContractorLab/Projects/YZ/Miniscope_data/Miniscope_data/Linear_track/BehavCamConcactenated_388/rotated_avi
# Cropped output directory: /Volumes/fsmresfiles/Basic_Sciences/Phys/ContractorLab/Projects/YZ/Miniscope_data/Miniscope_data/Linear_track/BehavCamConcactenated_388/rotated_and_cropped_avi
#                                             file_name  \
# 0   m388_01072025_14_29_09_concactenatedbehavCam00...
# 1   m388_01072025_14_37_41_concactenatedbehavCam00...
# 2   m388_01072025_14_49_45_concactenatedbehavCam00...
# 3   m388_02072025_14_48_02_concactenatedbehavCam00...
# 4   m388_03072025_14_28_38_concactenatedbehavCam00...
# 5   m388_04072025_15_43_20_concactenatedbehavCam00...
# 6   m388_05072025_16_21_10_concactenatedbehavCam00...
# 7   m388_06072025_14_53_04_concactenatedbehavCam00...
# 8   m388_07072025_11_39_31_concactenatedbehavCam00...
# 9   m388_08072025_13_48_35_concactenatedbehavCam00...
# 10  m388_09072025_11_51_21_concactenatedbehavCam00...
# 11  m388_10072025_14_00_39_concactenatedbehavCam00...
# 12  m388_11072025_14_35_14_concactenatedbehavCam00...
#
#                                            input_file  angle_degrees  crop_x  \
# 0   /Volumes/fsmresfiles/Basic_Sciences/Phys/Contr...           29.5      48
# 1   /Volumes/fsmresfiles/Basic_Sciences/Phys/Contr...           29.5      48
# 2   /Volumes/fsmresfiles/Basic_Sciences/Phys/Contr...           29.5      48
# 3   /Volumes/fsmresfiles/Basic_Sciences/Phys/Contr...           29.5      48
# 4   /Volumes/fsmresfiles/Basic_Sciences/Phys/Contr...           29.5      48
# 5   /Volumes/fsmresfiles/Basic_Sciences/Phys/Contr...           29.5      48
# 6   /Volumes/fsmresfiles/Basic_Sciences/Phys/Contr...           29.5      48
# 7   /Volumes/fsmresfiles/Basic_Sciences/Phys/Contr...           29.5      48
# 8   /Volumes/fsmresfiles/Basic_Sciences/Phys/Contr...           29.5      48
# 9   /Volumes/fsmresfiles/Basic_Sciences/Phys/Contr...           29.5      48
# 10  /Volumes/fsmresfiles/Basic_Sciences/Phys/Contr...           29.5      48
# 11  /Volumes/fsmresfiles/Basic_Sciences/Phys/Contr...           29.5      48
# 12  /Volumes/fsmresfiles/Basic_Sciences/Phys/Contr...           29.5      48
#
#     crop_y  crop_width  crop_height  enabled
# 0      377         668           36     True
# 1      377         668           36     True
# 2      377         668           36     True
# 3      377         668           36     True
# 4      377         668           36     True
# 5      377         668           36     True
# 6      377         668           36     True
# 7      377         668           36     True
# 8      377         668           36     True
# 9      377         668           36     True
# 10     377         668           36     True
# 11     377         668           36     True
# 12     377         668           36     True

# %%
# Edit per-video settings here before running previews or batch export.

#default_crop_box = normalize_crop_box(vertices=[(Bx, By), (Bx+Width, By), (Bx+Width, By+Height), (Bx, By+Height)])
# Examples:
# video_config_df.loc[video_config_df['file_name'] == 'm992_12302024_19_59_56_concactenatedbehavCam00_behavCam15.mp4', 'angle_degrees'] = 28
#video_config_df.loc[video_config_df['file_name'] == 'm757_04102024_17_05_49_concactenatedbehavCam00_behavCam17.mp4', ['crop_x', 'crop_y', 'crop_width', 'crop_height']] = [66, 356, 660, 37]
#video_config_df.loc[video_config_df['file_name'] == 'm757_10102024_15_50_07_concactenatedbehavCam00_behavCam17.mp4', ['crop_x', 'crop_y', 'crop_width', 'crop_height']] = [71, 354, 654, 40]

# video_config_df.loc[video_config_df['file_name'] == 'some_file.mp4', 'enabled'] = False

video_config_df
# Out:
#                                             file_name  \
# 0   m388_01072025_14_29_09_concactenatedbehavCam00...
# 1   m388_01072025_14_37_41_concactenatedbehavCam00...
# 2   m388_01072025_14_49_45_concactenatedbehavCam00...
# 3   m388_02072025_14_48_02_concactenatedbehavCam00...
# 4   m388_03072025_14_28_38_concactenatedbehavCam00...
# 5   m388_04072025_15_43_20_concactenatedbehavCam00...
# 6   m388_05072025_16_21_10_concactenatedbehavCam00...
# 7   m388_06072025_14_53_04_concactenatedbehavCam00...
# 8   m388_07072025_11_39_31_concactenatedbehavCam00...
# 9   m388_08072025_13_48_35_concactenatedbehavCam00...
# 10  m388_09072025_11_51_21_concactenatedbehavCam00...
# 11  m388_10072025_14_00_39_concactenatedbehavCam00...
# 12  m388_11072025_14_35_14_concactenatedbehavCam00...
#
#                                            input_file  angle_degrees  crop_x  \
# 0   /Volumes/fsmresfiles/Basic_Sciences/Phys/Contr...           29.5      48
# 1   /Volumes/fsmresfiles/Basic_Sciences/Phys/Contr...           29.5      48
# 2   /Volumes/fsmresfiles/Basic_Sciences/Phys/Contr...           29.5      48
# 3   /Volumes/fsmresfiles/Basic_Sciences/Phys/Contr...           29.5      48
# 4   /Volumes/fsmresfiles/Basic_Sciences/Phys/Contr...           29.5      48
# 5   /Volumes/fsmresfiles/Basic_Sciences/Phys/Contr...           29.5      48
# 6   /Volumes/fsmresfiles/Basic_Sciences/Phys/Contr...           29.5      48
# 7   /Volumes/fsmresfiles/Basic_Sciences/Phys/Contr...           29.5      48
# 8   /Volumes/fsmresfiles/Basic_Sciences/Phys/Contr...           29.5      48
# 9   /Volumes/fsmresfiles/Basic_Sciences/Phys/Contr...           29.5      48
# 10  /Volumes/fsmresfiles/Basic_Sciences/Phys/Contr...           29.5      48
# 11  /Volumes/fsmresfiles/Basic_Sciences/Phys/Contr...           29.5      48
# 12  /Volumes/fsmresfiles/Basic_Sciences/Phys/Contr...           29.5      48
#
#     crop_y  crop_width  crop_height  enabled
# 0      377         668           36     True
# 1      377         668           36     True
# 2      377         668           36     True
# 3      377         668           36     True
# 4      377         668           36     True
# 5      377         668           36     True
# 6      377         668           36     True
# 7      377         668           36     True
# 8      377         668           36     True
# 9      377         668           36     True
# 10     377         668           36     True
# 11     377         668           36     True
# 12     377         668           36     True

# %%
rotation_preview_results = preview_rotation_only(
    config_df=video_config_df,
    preview_time_fraction=preview_time_fraction,
)

rotation_preview_results
# Out:
# Rotation previews:   0%|                               | 0/13 [00:00<?, ?file/s]
# ### Rotation preview: m388_01072025_14_29_09_concactenatedbehavCam00_behavCam03.mp4
# Angle: `29.5`
# Preview time: `26.00s`
# Rotated canvas: `793 x 732`
# Rotation previews:   8%|█▊                     | 1/13 [00:00<00:11,  1.08file/s]
# ### Rotation preview: m388_01072025_14_37_41_concactenatedbehavCam00_behavCam03.mp4
# Angle: `29.5`
# Preview time: `25.98s`
# Rotated canvas: `793 x 732`
# Rotation previews:  15%|███▌                   | 2/13 [00:01<00:07,  1.49file/s]
# ### Rotation preview: m388_01072025_14_49_45_concactenatedbehavCam00_behavCam03.mp4
# Angle: `29.5`
# Preview time: `25.93s`
# Rotated canvas: `793 x 732`
# Rotation previews:  23%|█████▎                 | 3/13 [00:01<00:05,  1.70file/s]
# ### Rotation preview: m388_02072025_14_48_02_concactenatedbehavCam00_behavCam20.mp4
# Angle: `29.5`
# Preview time: `171.38s`
# Rotated canvas: `793 x 732`
# Rotation previews:  31%|███████                | 4/13 [00:02<00:04,  1.82file/s]
# ### Rotation preview: m388_03072025_14_28_38_concactenatedbehavCam00_behavCam20.mp4
# Angle: `29.5`
# Preview time: `171.43s`
# Rotated canvas: `793 x 732`
# Rotation previews:  38%|████████▊              | 5/13 [00:02<00:04,  1.87file/s]
# ### Rotation preview: m388_04072025_15_43_20_concactenatedbehavCam00_behavCam20.mp4
# Angle: `29.5`
# Preview time: `171.44s`
# Rotated canvas: `793 x 732`
# Rotation previews:  46%|██████████▌            | 6/13 [00:03<00:03,  1.92file/s]
# ### Rotation preview: m388_05072025_16_21_10_concactenatedbehavCam00_behavCam20.mp4
# Angle: `29.5`
# Preview time: `171.43s`
# Rotated canvas: `793 x 732`
# Rotation previews:  54%|████████████▍          | 7/13 [00:03<00:03,  1.96file/s]
# ### Rotation preview: m388_06072025_14_53_04_concactenatedbehavCam00_behavCam20.mp4
# Angle: `29.5`
# Preview time: `171.43s`
# Rotated canvas: `793 x 732`
# Rotation previews:  62%|██████████████▏        | 8/13 [00:04<00:02,  1.98file/s]
# ### Rotation preview: m388_07072025_11_39_31_concactenatedbehavCam00_behavCam20.mp4
# Angle: `29.5`
# Preview time: `171.42s`
# Rotated canvas: `793 x 732`
# Rotation previews:  69%|███████████████▉       | 9/13 [00:04<00:01,  2.00file/s]
# ### Rotation preview: m388_08072025_13_48_35_concactenatedbehavCam00_behavCam20.mp4
# Angle: `29.5`
# Preview time: `171.39s`
# Rotated canvas: `793 x 732`
# Rotation previews:  77%|████████████████▉     | 10/13 [00:05<00:01,  2.01file/s]
# ### Rotation preview: m388_09072025_11_51_21_concactenatedbehavCam00_behavCam20.mp4
# Angle: `29.5`
# Preview time: `171.44s`
# Rotated canvas: `793 x 732`
# Rotation previews:  85%|██████████████████▌   | 11/13 [00:05<00:00,  2.03file/s]
# ### Rotation preview: m388_10072025_14_00_39_concactenatedbehavCam00_behavCam20.mp4
# Angle: `29.5`
# Preview time: `171.43s`
# Rotated canvas: `793 x 732`
# Rotation previews:  92%|████████████████████▎ | 12/13 [00:06<00:00,  2.03file/s]
# ### Rotation preview: m388_11072025_14_35_14_concactenatedbehavCam00_behavCam20.mp4
# Angle: `29.5`
# Preview time: `171.45s`
# Rotated canvas: `793 x 732`
# Rotation previews: 100%|██████████████████████| 13/13 [00:06<00:00,  1.90file/s]
#                                             file_name  preview_time_sec  \
# 0   m388_01072025_14_29_09_concactenatedbehavCam00...         26.000000
# 1   m388_01072025_14_37_41_concactenatedbehavCam00...         25.975000
# 2   m388_01072025_14_49_45_concactenatedbehavCam00...         25.933333
# 3   m388_02072025_14_48_02_concactenatedbehavCam00...        171.383333
# 4   m388_03072025_14_28_38_concactenatedbehavCam00...        171.433334
# 5   m388_04072025_15_43_20_concactenatedbehavCam00...        171.441666
# 6   m388_05072025_16_21_10_concactenatedbehavCam00...        171.425000
# 7   m388_06072025_14_53_04_concactenatedbehavCam00...        171.425000
# 8   m388_07072025_11_39_31_concactenatedbehavCam00...        171.416666
# 9   m388_08072025_13_48_35_concactenatedbehavCam00...        171.391667
# 10  m388_09072025_11_51_21_concactenatedbehavCam00...        171.441666
# 11  m388_10072025_14_00_39_concactenatedbehavCam00...        171.425000
# 12  m388_11072025_14_35_14_concactenatedbehavCam00...        171.450000
#
#     angle_degrees  rotated_width  rotated_height
# 0            29.5            793             732
# 1            29.5            793             732
# 2            29.5            793             732
# 3            29.5            793             732
# 4            29.5            793             732
# 5            29.5            793             732
# 6            29.5            793             732
# 7            29.5            793             732
# 8            29.5            793             732
# 9            29.5            793             732
# 10           29.5            793             732
# 11           29.5            793             732
# 12           29.5            793             732

# %%
cropped_preview_results = preview_rotated_and_cropped(
    config_df=video_config_df,
    preview_time_fraction=preview_time_fraction,
)

cropped_preview_results
# Out:
# Crop previews:   0%|                                   | 0/13 [00:00<?, ?file/s]
# ### Rotation + crop preview: m388_01072025_14_29_09_concactenatedbehavCam00_behavCam03.mp4
# Angle: `29.5`
# Preview time: `26.00s`
# Crop box: `x=48, y=377, w=668, h=36`
# Crop previews:   8%|██                         | 1/13 [00:00<00:11,  1.02file/s]
# ### Rotation + crop preview: m388_01072025_14_37_41_concactenatedbehavCam00_behavCam03.mp4
# Angle: `29.5`
# Preview time: `25.98s`
# Crop box: `x=48, y=377, w=668, h=36`
# Crop previews:  15%|████▏                      | 2/13 [00:01<00:08,  1.37file/s]
# ### Rotation + crop preview: m388_01072025_14_49_45_concactenatedbehavCam00_behavCam03.mp4
# Angle: `29.5`
# Preview time: `25.93s`
# Crop box: `x=48, y=377, w=668, h=36`
# Crop previews:  23%|██████▏                    | 3/13 [00:02<00:06,  1.59file/s]
# ### Rotation + crop preview: m388_02072025_14_48_02_concactenatedbehavCam00_behavCam20.mp4
# Angle: `29.5`
# Preview time: `171.38s`
# Crop box: `x=48, y=377, w=668, h=36`
# Crop previews:  31%|████████▎                  | 4/13 [00:02<00:05,  1.73file/s]
# ### Rotation + crop preview: m388_03072025_14_28_38_concactenatedbehavCam00_behavCam20.mp4
# Angle: `29.5`
# Preview time: `171.43s`
# Crop box: `x=48, y=377, w=668, h=36`
# Crop previews:  38%|██████████▍                | 5/13 [00:03<00:04,  1.77file/s]
# ### Rotation + crop preview: m388_04072025_15_43_20_concactenatedbehavCam00_behavCam20.mp4
# Angle: `29.5`
# Preview time: `171.44s`
# Crop box: `x=48, y=377, w=668, h=36`
# Crop previews:  46%|████████████▍              | 6/13 [00:03<00:03,  1.82file/s]
# ### Rotation + crop preview: m388_05072025_16_21_10_concactenatedbehavCam00_behavCam20.mp4
# Angle: `29.5`
# Preview time: `171.43s`
# Crop box: `x=48, y=377, w=668, h=36`
# Crop previews:  54%|██████████████▌            | 7/13 [00:04<00:03,  1.83file/s]
# ### Rotation + crop preview: m388_06072025_14_53_04_concactenatedbehavCam00_behavCam20.mp4
# Angle: `29.5`
# Preview time: `171.43s`
# Crop box: `x=48, y=377, w=668, h=36`
# Crop previews:  62%|████████████████▌          | 8/13 [00:04<00:02,  1.82file/s]
# ### Rotation + crop preview: m388_07072025_11_39_31_concactenatedbehavCam00_behavCam20.mp4
# Angle: `29.5`
# Preview time: `171.42s`
# Crop box: `x=48, y=377, w=668, h=36`
# Crop previews:  69%|██████████████████▋        | 9/13 [00:05<00:02,  1.83file/s]
# ### Rotation + crop preview: m388_08072025_13_48_35_concactenatedbehavCam00_behavCam20.mp4
# Angle: `29.5`
# Preview time: `171.39s`
# Crop box: `x=48, y=377, w=668, h=36`
# Crop previews:  77%|████████████████████      | 10/13 [00:05<00:01,  1.71file/s]
# ### Rotation + crop preview: m388_09072025_11_51_21_concactenatedbehavCam00_behavCam20.mp4
# Angle: `29.5`
# Preview time: `171.44s`
# Crop box: `x=48, y=377, w=668, h=36`
# Crop previews:  85%|██████████████████████    | 11/13 [00:06<00:01,  1.76file/s]
# ### Rotation + crop preview: m388_10072025_14_00_39_concactenatedbehavCam00_behavCam20.mp4
# Angle: `29.5`
# Preview time: `171.43s`
# Crop box: `x=48, y=377, w=668, h=36`
# Crop previews:  92%|████████████████████████  | 12/13 [00:06<00:00,  1.83file/s]
# ### Rotation + crop preview: m388_11072025_14_35_14_concactenatedbehavCam00_behavCam20.mp4
# Angle: `29.5`
# Preview time: `171.45s`
# Crop box: `x=48, y=377, w=668, h=36`
# Crop previews: 100%|██████████████████████████| 13/13 [00:07<00:00,  1.74file/s]
#                                             file_name  preview_time_sec  \
# 0   m388_01072025_14_29_09_concactenatedbehavCam00...         26.000000
# 1   m388_01072025_14_37_41_concactenatedbehavCam00...         25.975000
# 2   m388_01072025_14_49_45_concactenatedbehavCam00...         25.933333
# 3   m388_02072025_14_48_02_concactenatedbehavCam00...        171.383333
# 4   m388_03072025_14_28_38_concactenatedbehavCam00...        171.433334
# 5   m388_04072025_15_43_20_concactenatedbehavCam00...        171.441666
# 6   m388_05072025_16_21_10_concactenatedbehavCam00...        171.425000
# 7   m388_06072025_14_53_04_concactenatedbehavCam00...        171.425000
# 8   m388_07072025_11_39_31_concactenatedbehavCam00...        171.416666
# 9   m388_08072025_13_48_35_concactenatedbehavCam00...        171.391667
# 10  m388_09072025_11_51_21_concactenatedbehavCam00...        171.441666
# 11  m388_10072025_14_00_39_concactenatedbehavCam00...        171.425000
# 12  m388_11072025_14_35_14_concactenatedbehavCam00...        171.450000
#
#     angle_degrees  crop_x  crop_y  crop_width  crop_height
# 0            29.5      48     377         668           36
# 1            29.5      48     377         668           36
# 2            29.5      48     377         668           36
# 3            29.5      48     377         668           36
# 4            29.5      48     377         668           36
# 5            29.5      48     377         668           36
# 6            29.5      48     377         668           36
# 7            29.5      48     377         668           36
# 8            29.5      48     377         668           36
# 9            29.5      48     377         668           36
# 10           29.5      48     377         668           36
# 11           29.5      48     377         668           36
# 12           29.5      48     377         668           36

# %%
rotation_batch_results = batch_rotate_from_config(
    config_df=video_config_df,
    rotated_output_dir=rotated_output_dir,
    overwrite=overwrite_existing,
)

rotation_batch_results
# Out:
# Rotate files:   0%|                                    | 0/13 [00:00<?, ?file/s]
# m388_01072025_14_29_09_concactenatedbehavCam00_behavCam03.mp4:   0%| | 0/52.0 [0
# m388_01072025_14_29_09_concactenatedbehavCam00_behavCam03.mp4:  13%|▏| 6.766667/
# m388_01072025_14_29_09_concactenatedbehavCam00_behavCam03.mp4:  26%|▎| 13.6/52.0
# m388_01072025_14_29_09_concactenatedbehavCam00_behavCam03.mp4:  39%|▍| 20.216667
# m388_01072025_14_29_09_concactenatedbehavCam00_behavCam03.mp4:  48%|▍| 24.95/52.
# m388_01072025_14_29_09_concactenatedbehavCam00_behavCam03.mp4:  58%|▌| 29.916667
# m388_01072025_14_29_09_concactenatedbehavCam00_behavCam03.mp4:  67%|▋| 34.966667
# m388_01072025_14_29_09_concactenatedbehavCam00_behavCam03.mp4:  79%|▊| 40.883333
# m388_01072025_14_29_09_concactenatedbehavCam00_behavCam03.mp4:  89%|▉| 46.183333
# m388_01072025_14_29_09_concactenatedbehavCam00_behavCam03.mp4: 100%|█| 52.0/52.0
# Rotate files:   8%|██▏                         | 1/13 [00:06<01:12,  6.07s/file]
# m388_01072025_14_37_41_concactenatedbehavCam00_behavCam03.mp4:   0%| | 0/51.95 [
# m388_01072025_14_37_41_concactenatedbehavCam00_behavCam03.mp4:  13%|▏| 6.833333/
# m388_01072025_14_37_41_concactenatedbehavCam00_behavCam03.mp4:  27%|▎| 13.85/51.
# m388_01072025_14_37_41_concactenatedbehavCam00_behavCam03.mp4:  39%|▍| 20.033333
# m388_01072025_14_37_41_concactenatedbehavCam00_behavCam03.mp4:  52%|▌| 27.15/51.
# m388_01072025_14_37_41_concactenatedbehavCam00_behavCam03.mp4:  63%|▋| 32.983333
# m388_01072025_14_37_41_concactenatedbehavCam00_behavCam03.mp4:  74%|▋| 38.516667
# m388_01072025_14_37_41_concactenatedbehavCam00_behavCam03.mp4:  86%|▊| 44.916667
# m388_01072025_14_37_41_concactenatedbehavCam00_behavCam03.mp4:  97%|▉| 50.5/51.9
# m388_01072025_14_37_41_concactenatedbehavCam00_behavCam03.mp4: 100%|█| 51.95/51.
# Rotate files:  15%|████▎                       | 2/13 [00:11<01:02,  5.68s/file]
# m388_01072025_14_49_45_concactenatedbehavCam00_behavCam03.mp4:   0%| | 0/51.8666
# m388_01072025_14_49_45_concactenatedbehavCam00_behavCam03.mp4:  12%| | 6.333333/
# m388_01072025_14_49_45_concactenatedbehavCam00_behavCam03.mp4:  19%|▏| 10.033333
# m388_01072025_14_49_45_concactenatedbehavCam00_behavCam03.mp4:  30%|▎| 15.633333
# m388_01072025_14_49_45_concactenatedbehavCam00_behavCam03.mp4:  43%|▍| 22.216667
# m388_01072025_14_49_45_concactenatedbehavCam00_behavCam03.mp4:  55%|▌| 28.516667
# m388_01072025_14_49_45_concactenatedbehavCam00_behavCam03.mp4:  65%|▋| 33.916667
# m388_01072025_14_49_45_concactenatedbehavCam00_behavCam03.mp4:  77%|▊| 39.8/51.8
# m388_01072025_14_49_45_concactenatedbehavCam00_behavCam03.mp4:  87%|▊| 45.3/51.8
# m388_01072025_14_49_45_concactenatedbehavCam00_behavCam03.mp4:  99%|▉| 51.35/51.
# Rotate files:  23%|██████▍                     | 3/13 [00:17<00:57,  5.72s/file]
# m388_02072025_14_48_02_concactenatedbehavCam00_behavCam20.mp4:   0%| | 0/342.766
# m388_02072025_14_48_02_concactenatedbehavCam00_behavCam20.mp4:   2%| | 6.816667/
# m388_02072025_14_48_02_concactenatedbehavCam00_behavCam20.mp4:   4%| | 13.783333
# m388_02072025_14_48_02_concactenatedbehavCam00_behavCam20.mp4:   6%| | 20.4/342.
# m388_02072025_14_48_02_concactenatedbehavCam00_behavCam20.mp4:   8%| | 27.45/342
# m388_02072025_14_48_02_concactenatedbehavCam00_behavCam20.mp4:   9%| | 32.15/342
# m388_02072025_14_48_02_concactenatedbehavCam00_behavCam20.mp4:  11%| | 36.75/342
# m388_02072025_14_48_02_concactenatedbehavCam00_behavCam20.mp4:  12%| | 41.566667
# m388_02072025_14_48_02_concactenatedbehavCam00_behavCam20.mp4:  14%|▏| 46.666667
# m388_02072025_14_48_02_concactenatedbehavCam00_behavCam20.mp4:  15%|▏| 52.383333
# m388_02072025_14_48_02_concactenatedbehavCam00_behavCam20.mp4:  17%|▏| 57.966667
# m388_02072025_14_48_02_concactenatedbehavCam00_behavCam20.mp4:  18%|▏| 62.033333
# m388_02072025_14_48_02_concactenatedbehavCam00_behavCam20.mp4:  20%|▏| 67.033333
# m388_02072025_14_48_02_concactenatedbehavCam00_behavCam20.mp4:  21%|▏|
# m388_10072025_14_00_39_concactenatedbehavCam00_behavCam20.mp4: 100%|█| 342.85/34
# Rotate files:  92%|████████████████████████▉  | 12/13 [05:21<00:33, 33.39s/file]
# m388_11072025_14_35_14_concactenatedbehavCam00_behavCam20.mp4:   0%| | 0/342.9 [
# m388_11072025_14_35_14_concactenatedbehavCam00_behavCam20.mp4:   2%| | 6.55/342.
# m388_11072025_14_35_14_concactenatedbehavCam00_behavCam20.mp4:   4%| | 13.083333
# m388_11072025_14_35_14_concactenatedbehavCam00_behavCam20.mp4:   6%| | 19.25/342
# m388_11072025_14_35_14_concactenatedbehavCam00_behavCam20.mp4:   7%| | 25.533333
# m388_11072025_14_35_14_concactenatedbehavCam00_behavCam20.mp4:   9%| | 30.183333
# m388_11072025_14_35_14_concactenatedbehavCam00_behavCam20.mp4:  11%| | 36.233333
# m388_11072025_14_35_14_concactenatedbehavCam00_behavCam20.mp4:  12%| | 40.95/342
# m388_11072025_14_35_14_concactenatedbehavCam00_behavCam20.mp4:  14%|▏| 46.916667
# m388_11072025_14_35_14_concactenatedbehavCam00_behavCam20.mp4:  15%|▏| 51.816667
# m388_11072025_14_35_14_concactenatedbehavCam00_behavCam20.mp4:  17%|▏| 57.483333
# m388_11072025_14_35_14_concactenatedbehavCam00_behavCam20.mp4:  18%|▏| 60.583333
# m388_11072025_14_35_14_concactenatedbehavCam00_behavCam20.mp4:  19%|▏| 66.55/342
# m388_11072025_14_35_14_concactenatedbehavCam00_behavCam20.mp4:  21%|▏| 72.1/342.
# m388_11072025_14_35_14_concactenatedbehavCam00_behavCam20.mp4:  23%|▏| 77.6/342.
# m388_11072025_14_35_14_concactenatedbehavCam00_behavCam20.mp4:  24%|▏| 83.533333
# m388_11072025_14_35_14_concactenatedbehavCam00_behavCam20.mp4:  26%|▎| 88.666667
# m388_11072025_14_35_14_concactenatedbehavCam00_behavCam20.mp4:  28%|▎| 94.766667
# m388_11072025_14_35_14_concactenatedbehavCam00_behavCam20.mp4:  29%|▎| 100.05/34
# m388_11072025_14_35_14_concactenatedbehavCam00_behavCam20.mp4:  31%|▎| 106.11666
# m388_11072025_14_35_14_concactenatedbehavCam00_behavCam20.mp4:  32%|▎| 111.08333
# m388_11072025_14_35_14_concactenatedbehavCam00_behavCam20.mp4:  34%|▎| 116.95/34
# m388_11072025_14_35_14_concactenatedbehavCam00_behavCam20.mp4:  35%|▎| 120.11666
# m388_11072025_14_35_14_concactenatedbehavCam00_behavCam20.mp4:  37%|▎| 125.5/342
# m388_11072025_14_35_14_concactenatedbehavCam00_behavCam20.mp4:  38%|▍| 131.28333
# m388_11072025_14_35_14_concactenatedbehavCam00_behavCam20.mp4:  40%|▍| 136.55/34
# m388_11072025_14_35_14_concactenatedbehavCam00_behavCam20.mp4:  41%|▍| 142.01666
# m388_11072025_14_35_14_concactenatedbehavCam00_behavCam20.mp4:  43%|▍| 147.6/342
# m388_11072025_14_35_14_concactenatedbehavCam00_behavCam20.mp4:  45%|▍| 153.5/342
# m388_11072025_14_35_14_concactenatedbehavCam00_behavCam20.mp4:  46%|▍| 158.65/34
# m388_11072025_14_35_14_concactenatedbehavCam00_behavCam20.mp4:  48%|▍| 164.76666
# m388_11072025_14_35_14_concactenatedbehavCam00_behavCam20.mp4:  49%|▍| 167.88333
# m388_11072025_14_35_14_concactenatedbehavCam00_behavCam20.mp4:  51%|▌| 173.36666
# m388_11072025_14_35_14_concactenatedbehavCam00_behavCam20.mp4:  52%|▌| 178.88333
# m388_11072025_14_35_14_concactenatedbehavCam00_behavCam20.mp4:  54%|▌| 184.51666
# m388_11072025_14_35_14_concactenatedbehavCam00_behavCam20.mp4:  55%|▌| 190.1/342
# m388_11072025_14_35_14_concactenatedbehavCam00_behavCam20.mp4:  57%|▌| 195.48333
# m388_11072025_14_35_14_concactenatedbehavCam00_behavCam20.mp4:  59%|▌| 201.48333
# m388_11072025_14_35_14_concactenatedbehavCam00_behavCam20.mp4:  60%|▌| 206.86666
# m388_11072025_14_35_14_concactenatedbehavCam00_behavCam20.mp4:  62%|▌| 212.56666
# m388_11072025_14_35_14_concactenatedbehavCam00_behavCam20.mp4:  64%|▋| 217.85/34
# m388_11072025_14_35_14_concactenatedbehavCam00_behavCam20.mp4:  65%|▋| 223.86666
# m388_11072025_14_35_14_concactenatedbehavCam00_behavCam20.mp4:  66%|▋| 226.86666
# m388_11072025_14_35_14_concactenatedbehavCam00_behavCam20.mp4:  68%|▋| 232.2/342
# m388_11072025_14_35_14_concactenatedbehavCam00_behavCam20.mp4:  69%|▋| 237.9/342
# m388_11072025_14_35_14_concactenatedbehavCam00_behavCam20.mp4:  71%|▋| 243.3/342
# m388_11072025_14_35_14_concactenatedbehavCam00_behavCam20.mp4:  73%|▋| 249.25/34
# m388_11072025_14_35_14_concactenatedbehavCam00_behavCam20.mp4:  74%|▋| 254.6/342
# m388_11072025_14_35_14_concactenatedbehavCam00_behavCam20.mp4:  76%|▊| 260.7/342
# m388_11072025_14_35_14_concactenatedbehavCam00_behavCam20.mp4:  78%|▊| 266.01666
# m388_11072025_14_35_14_concactenatedbehavCam00_behavCam20.mp4:  79%|▊| 272.08333
# m388_11072025_14_35_14_concactenatedbehavCam00_behavCam20.mp4:  80%|▊| 275.88333
# m388_11072025_14_35_14_concactenatedbehavCam00_behavCam20.mp4:  82%|▊| 281.16666
# m388_11072025_14_35_14_concactenatedbehavCam00_behavCam20.mp4:  84%|▊| 287.2/342
# m388_11072025_14_35_14_concactenatedbehavCam00_behavCam20.mp4:  85%|▊| 292.53333
# m388_11072025_14_35_14_concactenatedbehavCam00_behavCam20.mp4:  87%|▊| 298.1/342
# m388_11072025_14_35_14_concactenatedbehavCam00_behavCam20.mp4:  88%|▉| 303.4/342
# m388_11072025_14_35_14_concactenatedbehavCam00_behavCam20.mp4:  90%|▉| 309.3/342
# m388_11072025_14_35_14_concactenatedbehavCam00_behavCam20.mp4:  92%|▉| 314.68333
# m388_11072025_14_35_14_concactenatedbehavCam00_behavCam20.mp4:  93%|▉| 320.46666
# m388_11072025_14_35_14_concactenatedbehavCam00_behavCam20.mp4:  95%|▉| 326.11666
# m388_11072025_14_35_14_concactenatedbehavCam00_behavCam20.mp4:  97%|▉| 331.51666
# m388_11072025_14_35_14_concactenatedbehavCam00_behavCam20.mp4:  98%|▉| 337.3/342
# m388_11072025_14_35_14_concactenatedbehavCam00_behavCam20.mp4: 100%|▉| 342.56666
# Rotate files: 100%|███████████████████████████| 13/13 [05:54<00:00, 27.26s/file]
#                                            input_file  \
# 0   /Volumes/fsmresfiles/Basic_Sciences/Phys/Contr...
# 1   /Volumes/fsmresfiles/Basic_Sciences/Phys/Contr...
# 2   /Volumes/fsmresfiles/Basic_Sciences/Phys/Contr...
# 3   /Volumes/fsmresfiles/Basic_Sciences/Phys/Contr...
# 4   /Volumes/fsmresfiles/Basic_Sciences/Phys/Contr...
# 5   /Volumes/fsmresfiles/Basic_Sciences/Phys/Contr...
# 6   /Volumes/fsmresfiles/Basic_Sciences/Phys/Contr...
# 7   /Volumes/fsmresfiles/Basic_Sciences/Phys/Contr...
# 8   /Volumes/fsmresfiles/Basic_Sciences/Phys/Contr...
# 9   /Volumes/fsmresfiles/Basic_Sciences/Phys/Contr...
# 10  /Volumes/fsmresfiles/Basic_Sciences/Phys/Contr...
# 11  /Volumes/fsmresfiles/Basic_Sciences/Phys/Contr...
# 12  /Volumes/fsmresfiles/Basic_Sciences/Phys/Contr...
#
#                                           output_file  duration_sec  \
# 0   /Volumes/fsmresfiles/Basic_Sciences/Phys/Contr...     52.000000
# 1   /Volumes/fsmresfiles/Basic_Sciences/Phys/Contr...     51.950000
# 2   /Volumes/fsmresfiles/Basic_Sciences/Phys/Contr...     51.866667
# 3   /Volumes/fsmresfiles/Basic_Sciences/Phys/Contr...    342.766667
# 4   /Volumes/fsmresfiles/Basic_Sciences/Phys/Contr...    342.866667
# 5   /Volumes/fsmresfiles/Basic_Sciences/Phys/Contr...    342.883333
# 6   /Volumes/fsmresfiles/Basic_Sciences/Phys/Contr...    342.850000
# 7   /Volumes/fsmresfiles/Basic_Sciences/Phys/Contr...    342.850000
# 8   /Volumes/fsmresfiles/Basic_Sciences/Phys/Contr...    342.833333
# 9   /Volumes/fsmresfiles/Basic_Sciences/Phys/Contr...    342.783333
# 10  /Volumes/fsmresfiles/Basic_Sciences/Phys/Contr...    342.883333
# 11  /Volumes/fsmresfiles/Basic_Sciences/Phys/Contr...    342.850000
# 12  /Volumes/fsmresfiles/Basic_Sciences/Phys/Contr...    342.900000
#
#    input_codec  rotated_width  rotated_height  angle_degrees     status
# 0        mpeg4            793             732           29.5  processed
# 1        mpeg4            793             732           29.5  processed
# 2        mpeg4            793             732           29.5  processed
# 3        mpeg4            793             732           29.5  processed
# 4        mpeg4            793             732           29.5  processed
# 5        mpeg4            793             732           29.5  processed
# 6        mpeg4            793             732           29.5  processed
# 7        mpeg4            793             732           29.5  processed
# 8        mpeg4            793             732           29.5  processed
# 9        mpeg4            793             732           29.5  processed
# 10       mpeg4            793             732           29.5  processed
# 11       mpeg4            793             732           29.5  processed
# 12       mpeg4            793             732           29.5  processed

# %%
crop_batch_results = batch_crop_from_config(
    config_df=video_config_df,
    rotated_output_dir=rotated_output_dir,
    cropped_output_dir=cropped_output_dir,
    overwrite=overwrite_existing,
)

crop_batch_results
# Out:
# Crop files:   0%|                                      | 0/13 [00:00<?, ?file/s]
# m388_01072025_14_29_09_concactenatedbehavCam00_behavCam03_rotated.avi:   0%| | 0
# m388_01072025_14_29_09_concactenatedbehavCam00_behavCam03_rotated.avi:  13%|▏| 6
# m388_01072025_14_29_09_concactenatedbehavCam00_behavCam03_rotated.avi:  25%|▎| 1
# m388_01072025_14_29_09_concactenatedbehavCam00_behavCam03_rotated.avi:  38%|▍| 1
# m388_01072025_14_29_09_concactenatedbehavCam00_behavCam03_rotated.avi:  59%|▌| 3
# m388_01072025_14_29_09_concactenatedbehavCam00_behavCam03_rotated.avi:  65%|▋| 3
# m388_01072025_14_29_09_concactenatedbehavCam00_behavCam03_rotated.av