# %% [markdown]
# # Rotate And Crop Video Batch
#
# Batch-process concatenated behavior camera videos with per-video rotation and crop settings.
#
# Workflow:
# 1. Build a per-video config table.
# 2. Preview rotation only for each video.
# 3. Edit any per-video angles or crop boxes.
# 4. Preview rotation plus crop for each video.
# 5. Run the full batch export.

# %%
from pathlib import Path
import math
import ffmpeg
import pandas as pd
from IPython.display import Image, Markdown, display
from tqdm import tqdm


def probe_video(video_path):
    probe = ffmpeg.probe(str(video_path))
    video_stream = next(stream for stream in probe['streams'] if stream['codec_type'] == 'video')
    width = int(video_stream['width'])
    height = int(video_stream['height'])
    duration = float(video_stream['duration'])
    codec_name = video_stream.get('codec_name', 'Unknown')
    return {
        'width': width,
        'height': height,
        'duration_sec': duration,
        'codec_name': codec_name,
    }


def compute_rotated_canvas(width, height, angle_degrees):
    angle_rad = math.radians(angle_degrees)
    new_width = int(abs(width * math.cos(angle_rad)) + abs(height * math.sin(angle_rad)))
    new_height = int(abs(width * math.sin(angle_rad)) + abs(height * math.cos(angle_rad)))
    return angle_rad, new_width, new_height


def normalize_crop_box(crop_box=None, vertices=None):
    if crop_box is None and vertices is None:
        raise ValueError('Provide either crop_box or vertices.')

    if crop_box is not None:
        return {
            'crop_x': int(crop_box['crop_x']),
            'crop_y': int(crop_box['crop_y']),
            'crop_width': int(crop_box['crop_width']),
            'crop_height': int(crop_box['crop_height']),
        }

    x_coordinates = [v[0] for v in vertices]
    y_coordinates = [v[1] for v in vertices]
    x_min = min(x_coordinates)
    x_max = max(x_coordinates)
    y_min = min(y_coordinates)
    y_max = max(y_coordinates)
    return {
        'crop_x': int(x_min),
        'crop_y': int(y_min),
        'crop_width': int(x_max - x_min),
        'crop_height': int(y_max - y_min),
    }


def clamp_crop_box(crop_box, frame_width, frame_height):
    crop_x = max(0, int(crop_box['crop_x']))
    crop_y = max(0, int(crop_box['crop_y']))
    crop_width = int(crop_box['crop_width'])
    crop_height = int(crop_box['crop_height'])

    if crop_width <= 0 or crop_height <= 0:
        raise ValueError(f'Invalid crop size: {crop_width} x {crop_height}')

    if crop_x + crop_width > frame_width or crop_y + crop_height > frame_height:
        raise ValueError(
            f"Crop box {(crop_x, crop_y, crop_width, crop_height)} exceeds frame bounds {(frame_width, frame_height)}"
        )

    return {
        'crop_x': crop_x,
        'crop_y': crop_y,
        'crop_width': crop_width,
        'crop_height': crop_height,
    }


def build_output_path(input_path, output_dir, suffix):
    return output_dir / f'{input_path.stem}{suffix}.avi'


def build_rotated_output_path(input_path, output_dir):
    return build_output_path(input_path, output_dir, suffix='_rotated')


def build_cropped_output_path(input_path, output_dir):
    return build_output_path(input_path, output_dir, suffix='_rotated_cropped')


def build_video_config_df(input_dir, default_angle_degrees, default_crop_box, pattern='*.mp4'):
    input_dir = Path(input_dir)
    video_files = sorted(input_dir.glob(pattern))
    if not video_files:
        raise FileNotFoundError(f'No files matching {pattern!r} found in {input_dir}')

    rows = []
    for video_path in video_files:
        rows.append({
            'file_name': video_path.name,
            'input_file': str(video_path),
            'angle_degrees': float(default_angle_degrees),
            'crop_x': int(default_crop_box['crop_x']),
            'crop_y': int(default_crop_box['crop_y']),
            'crop_width': int(default_crop_box['crop_width']),
            'crop_height': int(default_crop_box['crop_height']),
            'enabled': True,
        })

    return pd.DataFrame(rows)


def build_rotated_stream(input_path, angle_degrees, preview_time_sec=None):
    info = probe_video(input_path)
    angle_rad, rotated_width, rotated_height = compute_rotated_canvas(
        info['width'], info['height'], angle_degrees
    )

    input_kwargs = {}
    if preview_time_sec is not None:
        input_kwargs['ss'] = max(0, float(preview_time_sec))

    stream = (
        ffmpeg
        .input(str(input_path), **input_kwargs)
        .filter(
            'pad',
            rotated_width,
            rotated_height,
            (rotated_width - info['width']) // 2,
            (rotated_height - info['height']) // 2,
            color='0xFFFFFF'
        )
        .filter('rotate', str(angle_rad))
    )

    transform_info = {
        'duration_sec': info['duration_sec'],
        'input_codec': info['codec_name'],
        'rotated_width': rotated_width,
        'rotated_height': rotated_height,
    }
    return stream, transform_info


def build_rotated_cropped_stream(input_path, angle_degrees, crop_box, preview_time_sec=None):
    stream, info = build_rotated_stream(
        input_path=input_path,
        angle_degrees=angle_degrees,
        preview_time_sec=preview_time_sec,
    )
    crop_box = clamp_crop_box(crop_box, info['rotated_width'], info['rotated_height'])
    stream = stream.filter(
        'crop',
        crop_box['crop_width'],
        crop_box['crop_height'],
        crop_box['crop_x'],
        crop_box['crop_y'],
    )
    info.update(crop_box)
    return stream, info


def render_frame_from_stream(stream, input_name):
    out, err = (
        stream
        .output('pipe:', vframes=1, format='image2', vcodec='png')
        .global_args('-loglevel', 'error')
        .run(capture_stdout=True, capture_stderr=True)
    )
    if not out:
        error_text = err.decode('utf-8', errors='replace').strip()
        raise RuntimeError(error_text or f'Could not render preview frame for {input_name}')
    return out


def preview_rotation_only(config_df, preview_time_fraction=0.5):
    results = []
    enabled_df = config_df.loc[config_df['enabled']].reset_index(drop=True)
    for row in tqdm(enabled_df.itertuples(index=False), total=len(enabled_df), desc='Rotation previews', unit='file'):
        input_path = Path(row.input_file)
        info = probe_video(input_path)
        preview_time_sec = info['duration_sec'] * preview_time_fraction
        stream, transform_info = build_rotated_stream(
            input_path=input_path,
            angle_degrees=row.angle_degrees,
            preview_time_sec=preview_time_sec,
        )
        image_bytes = render_frame_from_stream(stream, input_path.name)

        display(Markdown(
            f"### Rotation preview: {input_path.name}\n"
            f"Angle: `{row.angle_degrees}`  \n"
            f"Preview time: `{preview_time_sec:.2f}s`  \n"
            f"Rotated canvas: `{transform_info['rotated_width']} x {transform_info['rotated_height']}`"
        ))
        display(Image(data=image_bytes))

        results.append({
            'file_name': row.file_name,
            'preview_time_sec': preview_time_sec,
            'angle_degrees': row.angle_degrees,
            'rotated_width': transform_info['rotated_width'],
            'rotated_height': transform_info['rotated_height'],
        })

    return pd.DataFrame(results)


def preview_rotated_and_cropped(config_df, preview_time_fraction=0.5):
    results = []
    enabled_df = config_df.loc[config_df['enabled']].reset_index(drop=True)
    for row in tqdm(enabled_df.itertuples(index=False), total=len(enabled_df), desc='Crop previews', unit='file'):
        input_path = Path(row.input_file)
        info = probe_video(input_path)
        preview_time_sec = info['duration_sec'] * preview_time_fraction
        stream, transform_info = build_rotated_cropped_stream(
            input_path=input_path,
            angle_degrees=row.angle_degrees,
            crop_box={
                'crop_x': row.crop_x,
                'crop_y': row.crop_y,
                'crop_width': row.crop_width,
                'crop_height': row.crop_height,
            },
            preview_time_sec=preview_time_sec,
        )
        image_bytes = render_frame_from_stream(stream, input_path.name)

        display(Markdown(
            f"### Rotation + crop preview: {input_path.name}\n"
            f"Angle: `{row.angle_degrees}`  \n"
            f"Preview time: `{preview_time_sec:.2f}s`  \n"
            f"Crop box: `x={transform_info['crop_x']}, y={transform_info['crop_y']}, w={transform_info['crop_width']}, h={transform_info['crop_height']}`"
        ))
        display(Image(data=image_bytes))

        results.append({
            'file_name': row.file_name,
            'preview_time_sec': preview_time_sec,
            'angle_degrees': row.angle_degrees,
            'crop_x': transform_info['crop_x'],
            'crop_y': transform_info['crop_y'],
            'crop_width': transform_info['crop_width'],
            'crop_height': transform_info['crop_height'],
        })

    return pd.DataFrame(results)


def rotate_video_only(input_path, output_path, angle_degrees, overwrite=False):
    stream, info = build_rotated_stream(
        input_path=input_path,
        angle_degrees=angle_degrees,
    )

    ffmpeg_command = (
        stream
        .output(str(output_path), vcodec='mjpeg', qscale=3)
        .global_args('-progress', 'pipe:1', '-nostats', '-loglevel', 'error')
    )

    process = ffmpeg_command.run_async(
        pipe_stdout=True,
        pipe_stderr=True,
        overwrite_output=overwrite,
    )

    pbar = tqdm(
        total=info['duration_sec'],
        desc=input_path.name,
        unit='s',
        dynamic_ncols=True,
        leave=False,
    )

    for raw_line in process.stdout:
        line = raw_line.decode('utf-8', errors='replace').strip()
        if line.startswith('out_time_ms='):
            out_time_ms = int(line.split('=', 1)[1])
            current_time = out_time_ms / 1_000_000
            pbar.update(max(0, current_time - pbar.n))
        elif line == 'progress=end':
            break

    pbar.close()
    return_code = process.wait()
    stderr_output = process.stderr.read().decode('utf-8', errors='replace').strip()

    if return_code != 0:
        raise RuntimeError(stderr_output or f'ffmpeg failed with exit code {return_code}')

    return {
        'input_file': str(input_path),
        'output_file': str(output_path),
        'duration_sec': info['duration_sec'],
        'input_codec': info['input_codec'],
        'rotated_width': info['rotated_width'],
        'rotated_height': info['rotated_height'],
        'angle_degrees': angle_degrees,
    }


def crop_rotated_video(input_path, output_path, crop_box, overwrite=False):
    info = probe_video(input_path)
    crop_box = clamp_crop_box(crop_box, info['width'], info['height'])

    ffmpeg_command = (
        ffmpeg
        .input(str(input_path))
        .filter(
            'crop',
            crop_box['crop_width'],
            crop_box['crop_height'],
            crop_box['crop_x'],
            crop_box['crop_y'],
        )
        .output(str(output_path), vcodec='mjpeg', qscale=3)
        .global_args('-progress', 'pipe:1', '-nostats', '-loglevel', 'error')
    )

    process = ffmpeg_command.run_async(
        pipe_stdout=True,
        pipe_stderr=True,
        overwrite_output=overwrite,
    )

    pbar = tqdm(
        total=info['duration_sec'],
        desc=input_path.name,
        unit='s',
        dynamic_ncols=True,
        leave=False,
    )

    for raw_line in process.stdout:
        line = raw_line.decode('utf-8', errors='replace').strip()
        if line.startswith('out_time_ms='):
            out_time_ms = int(line.split('=', 1)[1])
            current_time = out_time_ms / 1_000_000
            pbar.update(max(0, current_time - pbar.n))
        elif line == 'progress=end':
            break

    pbar.close()
    return_code = process.wait()
    stderr_output = process.stderr.read().decode('utf-8', errors='replace').strip()

    if return_code != 0:
        raise RuntimeError(stderr_output or f'ffmpeg failed with exit code {return_code}')

    return {
        'input_file': str(input_path),
        'output_file': str(output_path),
        'duration_sec': info['duration_sec'],
        'input_codec': info['codec_name'],
        'crop_x': crop_box['crop_x'],
        'crop_y': crop_box['crop_y'],
        'crop_width': crop_box['crop_width'],
        'crop_height': crop_box['crop_height'],
    }


def batch_rotate_from_config(config_df, rotated_output_dir, overwrite=False):
    rotated_output_dir = Path(rotated_output_dir)
    rotated_output_dir.mkdir(parents=True, exist_ok=True)

    enabled_df = config_df.loc[config_df['enabled']].reset_index(drop=True)
    if enabled_df.empty:
        raise ValueError('No enabled videos found in config_df')

    results = []
    for row in tqdm(enabled_df.itertuples(index=False), total=len(enabled_df), desc='Rotate files', unit='file'):
        input_path = Path(row.input_file)
        output_path = build_rotated_output_path(input_path, rotated_output_dir)

        if output_path.exists() and not overwrite:
            results.append({
                'input_file': str(input_path),
                'output_file': str(output_path),
                'status': 'skipped_existing',
            })
            continue

        try:
            result = rotate_video_only(
                input_path=input_path,
                output_path=output_path,
                angle_degrees=row.angle_degrees,
                overwrite=overwrite,
            )
            result['status'] = 'processed'
            results.append(result)
        except Exception as exc:
            results.append({
                'input_file': str(input_path),
                'output_file': str(output_path),
                'status': 'error',
                'error': str(exc),
            })

    return pd.DataFrame(results)


def batch_crop_from_config(config_df, rotated_output_dir, cropped_output_dir, overwrite=False):
    rotated_output_dir = Path(rotated_output_dir)
    cropped_output_dir = Path(cropped_output_dir)
    cropped_output_dir.mkdir(parents=True, exist_ok=True)

    enabled_df = config_df.loc[config_df['enabled']].reset_index(drop=True)
    if enabled_df.empty:
        raise ValueError('No enabled videos found in config_df')

    results = []
    for row in tqdm(enabled_df.itertuples(index=False), total=len(enabled_df), desc='Crop files', unit='file'):
        original_input_path = Path(row.input_file)
        rotated_input_path = build_rotated_output_path(original_input_path, rotated_output_dir)
        output_path = build_cropped_output_path(original_input_path, cropped_output_dir)

        if not rotated_input_path.exists():
            results.append({
                'input_file': str(original_input_path),
                'rotated_input_file': str(rotated_input_path),
                'output_file': str(output_path),
                'status': 'missing_rotated_input',
            })
            continue

        if output_path.exists() and not overwrite:
            results.append({
                'input_file': str(original_input_path),
                'rotated_input_file': str(rotated_input_path),
                'output_file': str(output_path),
                'status': 'skipped_existing',
            })
            continue

        try:
            result = crop_rotated_video(
                input_path=rotated_input_path,
                output_path=output_path,
                crop_box={
                    'crop_x': row.crop_x,
                    'crop_y': row.crop_y,
                    'crop_width': row.crop_width,
                    'crop_height': row.crop_height,
                },
                overwrite=overwrite,
            )
            result['source_input_file'] = str(original_input_path)
            result['rotated_input_file'] = str(rotated_input_path)
            result['status'] = 'processed'
            results.append(result)
        except Exception as exc:
            results.append({
                'input_file': str(original_input_path),
                'rotated_input_file': str(rotated_input_path),
                'output_file': str(output_path),
                'status': 'error',
                'error': str(exc),
            })

    return pd.DataFrame(results)

# %%
input_dir = Path('/Volumes/fsmresfiles/Basic_Sciences/Phys/ContractorLab/Projects/YZ/Miniscope_data/Miniscope_data/Linear_track/BehavCamConcactenated_752')
rotated_output_dir = input_dir / 'rotated_avi'
cropped_output_dir = input_dir / 'rotated_and_cropped_avi'

Bx = 78
By = 360
Width = 658
Height = 41

default_angle_to_rotate = 30.5
default_crop_box = normalize_crop_box(vertices=[(Bx, By), (Bx+Width, By), (Bx+Width, By+Height), (Bx, By+Height)])
preview_time_fraction = 0.5
overwrite_existing = False

video_config_df = build_video_config_df(
    input_dir=input_dir,
    default_angle_degrees=default_angle_to_rotate,
    default_crop_box=default_crop_box,
    pattern='*.mp4',
)

print(f'Found {len(video_config_df)} input videos in {input_dir}')
print(f'Rotated output directory: {rotated_output_dir}')
print(f'Cropped output directory: {cropped_output_dir}')
video_config_df
# Out:
# Found 16 input videos in /Volumes/fsmresfiles/Basic_Sciences/Phys/ContractorLab/Projects/YZ/Miniscope_data/Miniscope_data/Linear_track/BehavCamConcactenated_752
# Rotated output directory: /Volumes/fsmresfiles/Basic_Sciences/Phys/ContractorLab/Projects/YZ/Miniscope_data/Miniscope_data/Linear_track/BehavCamConcactenated_752/rotated_avi
# Cropped output directory: /Volumes/fsmresfiles/Basic_Sciences/Phys/ContractorLab/Projects/YZ/Miniscope_data/Miniscope_data/Linear_track/BehavCamConcactenated_752/rotated_and_cropped_avi
#                                             file_name  \
# 0   m752_01012025_18_25_40_concactenatedbehavCam00...
# 1   m752_01102024_16_18_25_concactenatedbehavCam00...
# 2   m752_02012025_19_56_52_concactenatedbehavCam00...
# 3   m752_02102024_14_10_13_concactenatedbehavCam00...
# 4   m752_03102024_13_18_31_concactenatedbehavCam00...
# 5   m752_04012025_18_46_25_concactenatedbehavCam00...
# 6   m752_04102024_15_56_54_concactenatedbehavCam00...
# 7   m752_05012025_16_56_29_concactenatedbehavCam00...
# 8   m752_06012025_20_35_19_concactenatedbehavCam00...
# 9   m752_06012025_20_48_29_concactenatedbehavCam00...
# 10  m752_07012025_20_02_00_concactenatedbehavCam00...
# 11  m752_08012025_17_12_33_concactenatedbehavCam00...
# 12  m752_09012025_13_01_33_concactenatedbehavCam00...
# 13  m752_10012025_16_46_25_concactenatedbehavCam00...
# 14  m752_10102024_14_28_27_concactenatedbehavCam00...
# 15  m752_10102024_14_42_07_concactenatedbehavCam00...
#
#                                            input_file  angle_degrees  crop_x  \
# 0   /Volumes/fsmresfiles/Basic_Sciences/Phys/Contr...           30.5      78
# 1   /Volumes/fsmresfiles/Basic_Sciences/Phys/Contr...           30.5      78
# 2   /Volumes/fsmresfiles/Basic_Sciences/Phys/Contr...           30.5      78
# 3   /Volumes/fsmresfiles/Basic_Sciences/Phys/Contr...           30.5      78
# 4   /Volumes/fsmresfiles/Basic_Sciences/Phys/Contr...           30.5      78
# 5   /Volumes/fsmresfiles/Basic_Sciences/Phys/Contr...           30.5      78
# 6   /Volumes/fsmresfiles/Basic_Sciences/Phys/Contr...           30.5      78
# 7   /Volumes/fsmresfiles/Basic_Sciences/Phys/Contr...           30.5      78
# 8   /Volumes/fsmresfiles/Basic_Sciences/Phys/Contr...           30.5      78
# 9   /Volumes/fsmresfiles/Basic_Sciences/Phys/Contr...           30.5      78
# 10  /Volumes/fsmresfiles/Basic_Sciences/Phys/Contr...           30.5      78
# 11  /Volumes/fsmresfiles/Basic_Sciences/Phys/Contr...           30.5      78
# 12  /Volumes/fsmresfiles/Basic_Sciences/Phys/Contr...           30.5      78
# 13  /Volumes/fsmresfiles/Basic_Sciences/Phys/Contr...           30.5      78
# 14  /Volumes/fsmresfiles/Basic_Sciences/Phys/Contr...           30.5      78
# 15  /Volumes/fsmresfiles/Basic_Sciences/Phys/Contr...           30.5      78
#
#     crop_y  crop_width  crop_height  enabled
# 0      360         658           41     True
# 1      360         658           41     True
# 2      360         658           41     True
# 3      360         658           41     True
# 4      360         658           41     True
# 5      360         658           41     True
# 6      360         658           41     True
# 7      360         658           41     True
# 8      360         658           41     True
# 9      360         658           41     True
# 10     360         658           41     True
# 11     360         658           41     True
# 12     360         658           41     True
# 13     360         658           41     True
# 14     360         658           41     True
# 15     360         658           41     True

# %%
# Edit per-video settings here before running previews or batch export.

#default_crop_box = normalize_crop_box(vertices=[(Bx, By), (Bx+Width, By), (Bx+Width, By+Height), (Bx, By+Height)])
# Examples:
#video_config_df.loc[video_config_df['file_name'] == 'm992_12302024_19_59_56_concactenatedbehavCam00_behavCam15.mp4', 'angle_degrees'] = 28
video_config_df.loc[video_config_df['file_name'] == 'm752_01102024_16_18_25_concactenatedbehavCam00_behavCam17.mp4', ['crop_x', 'crop_y', 'crop_width', 'crop_height']] = [85, 351, 661, 45]
video_config_df.loc[video_config_df['file_name'] == 'm752_02102024_14_10_13_concactenatedbehavCam00_behavCam17.mp4', ['crop_x', 'crop_y', 'crop_width', 'crop_height']] = [85, 351, 662, 46]
video_config_df.loc[video_config_df['file_name'] == 'm752_03102024_13_18_31_concactenatedbehavCam00_behavCam17.mp4', ['crop_x', 'crop_y', 'crop_width', 'crop_height']] = [86, 351, 658, 45]
video_config_df.loc[video_config_df['file_name'] == 'm752_04102024_15_56_54_concactenatedbehavCam00_behavCam17.mp4', ['crop_x', 'crop_y', 'crop_width', 'crop_height']] = [66, 355, 659, 38]
video_config_df.loc[video_config_df['file_name'] == 'm752_10102024_14_28_27_concactenatedbehavCam00_behavCam07.mp4', ['crop_x', 'crop_y', 'crop_width', 'crop_height']] = [69, 354, 657, 39]
video_config_df.loc[video_config_df['file_name'] == 'm752_10102024_14_42_07_concactenatedbehavCam00_behavCam14.mp4', ['crop_x', 'crop_y', 'crop_width', 'crop_height']] = [66, 355, 661, 37]
# video_config_df.loc[video_config_df['file_name'] == 'some_file.mp4', 'enabled'] = False

video_config_df
# Out:
#                                             file_name  \
# 0   m752_01012025_18_25_40_concactenatedbehavCam00...
# 1   m752_01102024_16_18_25_concactenatedbehavCam00...
# 2   m752_02012025_19_56_52_concactenatedbehavCam00...
# 3   m752_02102024_14_10_13_concactenatedbehavCam00...
# 4   m752_03102024_13_18_31_concactenatedbehavCam00...
# 5   m752_04012025_18_46_25_concactenatedbehavCam00...
# 6   m752_04102024_15_56_54_concactenatedbehavCam00...
# 7   m752_05012025_16_56_29_concactenatedbehavCam00...
# 8   m752_06012025_20_35_19_concactenatedbehavCam00...
# 9   m752_06012025_20_48_29_concactenatedbehavCam00...
# 10  m752_07012025_20_02_00_concactenatedbehavCam00...
# 11  m752_08012025_17_12_33_concactenatedbehavCam00...
# 12  m752_09012025_13_01_33_concactenatedbehavCam00...
# 13  m752_10012025_16_46_25_concactenatedbehavCam00...
# 14  m752_10102024_14_28_27_concactenatedbehavCam00...
# 15  m752_10102024_14_42_07_concactenatedbehavCam00...
#
#                                            input_file  angle_degrees  crop_x  \
# 0   /Volumes/fsmresfiles/Basic_Sciences/Phys/Contr...           30.5      78
# 1   /Volumes/fsmresfiles/Basic_Sciences/Phys/Contr...           30.5      85
# 2   /Volumes/fsmresfiles/Basic_Sciences/Phys/Contr...           30.5      78
# 3   /Volumes/fsmresfiles/Basic_Sciences/Phys/Contr...           30.5      85
# 4   /Volumes/fsmresfiles/Basic_Sciences/Phys/Contr...           30.5      86
# 5   /Volumes/fsmresfiles/Basic_Sciences/Phys/Contr...           30.5      78
# 6   /Volumes/fsmresfiles/Basic_Sciences/Phys/Contr...           30.5      66
# 7   /Volumes/fsmresfiles/Basic_Sciences/Phys/Contr...           30.5      78
# 8   /Volumes/fsmresfiles/Basic_Sciences/Phys/Contr...           30.5      78
# 9   /Volumes/fsmresfiles/Basic_Sciences/Phys/Contr...           30.5      78
# 10  /Volumes/fsmresfiles/Basic_Sciences/Phys/Contr...           30.5      78
# 11  /Volumes/fsmresfiles/Basic_Sciences/Phys/Contr...           30.5      78
# 12  /Volumes/fsmresfiles/Basic_Sciences/Phys/Contr...           30.5      78
# 13  /Volumes/fsmresfiles/Basic_Sciences/Phys/Contr...           30.5      78
# 14  /Volumes/fsmresfiles/Basic_Sciences/Phys/Contr...           30.5      69
# 15  /Volumes/fsmresfiles/Basic_Sciences/Phys/Contr...           30.5      66
#
#     crop_y  crop_width  crop_height  enabled
# 0      360         658           41     True
# 1      351         661           45     True
# 2      360         658           41     True
# 3      351         662           46     True
# 4      351         658           45     True
# 5      360         658           41     True
# 6      355         659           38     True
# 7      360         658           41     True
# 8      360         658           41     True
# 9      360         658           41     True
# 10     360         658           41     True
# 11     360         658           41     True
# 12     360         658           41     True
# 13     360         658           41     True
# 14     354         657           39     True
# 15     355         661           37     True

# %%
rotation_preview_results = preview_rotation_only(
    config_df=video_config_df,
    preview_time_fraction=preview_time_fraction,
)

rotation_preview_results
# Out:
# Rotation previews:   0%|                               | 0/16 [00:00<?, ?file/s]
# ### Rotation preview: m752_01012025_18_25_40_concactenatedbehavCam00_behavCam17.mp4
# Angle: `30.5`
# Preview time: `143.39s`
# Rotated canvas: `795 x 738`
# Rotation previews:   6%|█▍                     | 1/16 [00:04<01:02,  4.14s/file]
# ### Rotation preview: m752_01102024_16_18_25_concactenatedbehavCam00_behavCam17.mp4
# Angle: `30.5`
# Preview time: `143.40s`
# Rotated canvas: `795 x 738`
# Rotation previews:  12%|██▉                    | 2/16 [00:04<00:28,  2.03s/file]
# ### Rotation preview: m752_02012025_19_56_52_concactenatedbehavCam00_behavCam17.mp4
# Angle: `30.5`
# Preview time: `143.45s`
# Rotated canvas: `795 x 738`
# Rotation previews:  19%|████▎                  | 3/16 [00:05<00:17,  1.33s/file]
# ### Rotation preview: m752_02102024_14_10_13_concactenatedbehavCam00_behavCam17.mp4
# Angle: `30.5`
# Preview time: `143.43s`
# Rotated canvas: `795 x 738`
# Rotation previews:  25%|█████▊                 | 4/16 [00:05<00:12,  1.01s/file]
# ### Rotation preview: m752_03102024_13_18_31_concactenatedbehavCam00_behavCam17.mp4
# Angle: `30.5`
# Preview time: `143.38s`
# Rotated canvas: `795 x 738`
# Rotation previews:  31%|███████▏               | 5/16 [00:06<00:09,  1.20file/s]
# ### Rotation preview: m752_04012025_18_46_25_concactenatedbehavCam00_behavCam13.mp4
# Angle: `30.5`
# Preview time: `108.78s`
# Rotated canvas: `795 x 738`
# Rotation previews:  38%|████████▋              | 6/16 [00:06<00:07,  1.37file/s]
# ### Rotation preview: m752_04102024_15_56_54_concactenatedbehavCam00_behavCam17.mp4
# Angle: `30.5`
# Preview time: `143.35s`
# Rotated canvas: `795 x 738`
# Rotation previews:  44%|██████████             | 7/16 [00:07<00:05,  1.52file/s]
# ### Rotation preview: m752_05012025_16_56_29_concactenatedbehavCam00_behavCam17.mp4
# Angle: `30.5`
# Preview time: `143.43s`
# Rotated canvas: `795 x 738`
# Rotation previews:  50%|███████████▌           | 8/16 [00:07<00:04,  1.64file/s]
# ### Rotation preview: m752_06012025_20_35_19_concactenatedbehavCam00_behavCam11.mp4
# Angle: `30.5`
# Preview time: `93.60s`
# Rotated canvas: `795 x 738`
# Rotation previews:  56%|████████████▉          | 9/16 [00:08<00:04,  1.74file/s]
# ### Rotation preview: m752_06012025_20_48_29_concactenatedbehavCam00_behavCam09.mp4
# Angle: `30.5`
# Preview time: `81.79s`
# Rotated canvas: `795 x 738`
# Rotation previews:  62%|█████████████▊        | 10/16 [00:08<00:03,  1.79file/s]
# ### Rotation preview: m752_07012025_20_02_00_concactenatedbehavCam00_behavCam17.mp4
# Angle: `30.5`
# Preview time: `143.38s`
# Rotated canvas: `795 x 738`
# Rotation previews:  69%|███████████████▏      | 11/16 [00:09<00:02,  1.84file/s]
# ### Rotation preview: m752_08012025_17_12_33_concactenatedbehavCam00_behavCam17.mp4
# Angle: `30.5`
# Preview time: `143.38s`
# Rotated canvas: `795 x 738`
# Rotation previews:  75%|████████████████▌     | 12/16 [00:09<00:02,  1.88file/s]
# ### Rotation preview: m752_09012025_13_01_33_concactenatedbehavCam00_behavCam17.mp4
# Angle: `30.5`
# Preview time: `143.45s`
# Rotated canvas: `795 x 738`
# Rotation previews:  81%|█████████████████▉    | 13/16 [00:10<00:01,  1.91file/s]
# ### Rotation preview: m752_10012025_16_46_25_concactenatedbehavCam00_behavCam17.mp4
# Angle: `30.5`
# Preview time: `143.45s`
# Rotated canvas: `795 x 738`
# Rotation previews:  88%|███████████████████▎  | 14/16 [00:10<00:01,  1.93file/s]
# ### Rotation preview: m752_10102024_14_28_27_concactenatedbehavCam00_behavCam07.mp4
# Angle: `30.5`
# Preview time: `59.17s`
# Rotated canvas: `795 x 738`
# Rotation previews:  94%|████████████████████▋ | 15/16 [00:11<00:00,  1.94file/s]
# ### Rotation preview: m752_10102024_14_42_07_concactenatedbehavCam00_behavCam14.mp4
# Angle: `30.5`
# Preview time: `123.33s`
# Rotated canvas: `795 x 738`
# Rotation previews: 100%|██████████████████████| 16/16 [00:11<00:00,  1.35file/s]
#                                             file_name  preview_time_sec  \
# 0   m752_01012025_18_25_40_concactenatedbehavCam00...        143.391667
# 1   m752_01102024_16_18_25_concactenatedbehavCam00...        143.400000
# 2   m752_02012025_19_56_52_concactenatedbehavCam00...        143.450000
# 3   m752_02102024_14_10_13_concactenatedbehavCam00...        143.433334
# 4   m752_03102024_13_18_31_concactenatedbehavCam00...        143.375000
# 5   m752_04012025_18_46_25_concactenatedbehavCam00...        108.783333
# 6   m752_04102024_15_56_54_concactenatedbehavCam00...        143.350000
# 7   m752_05012025_16_56_29_concactenatedbehavCam00...        143.433334
# 8   m752_06012025_20_35_19_concactenatedbehavCam00...         93.600000
# 9   m752_06012025_20_48_29_concactenatedbehavCam00...         81.791667
# 10  m752_07012025_20_02_00_concactenatedbehavCam00...        143.383333
# 11  m752_08012025_17_12_33_concactenatedbehavCam00...        143.383333
# 12  m752_09012025_13_01_33_concactenatedbehavCam00...        143.450000
# 13  m752_10012025_16_46_25_concactenatedbehavCam00...        143.450000
# 14  m752_10102024_14_28_27_concactenatedbehavCam00...         59.175000
# 15  m752_10102024_14_42_07_concactenatedbehavCam00...        123.333333
#
#     angle_degrees  rotated_width  rotated_height
# 0            30.5            795             738
# 1            30.5            795             738
# 2            30.5            795             738
# 3            30.5            795             738
# 4            30.5            795             738
# 5            30.5            795             738
# 6            30.5            795             738
# 7            30.5            795             738
# 8            30.5            795             738
# 9            30.5            795             738
# 10           30.5            795             738
# 11           30.5            795             738
# 12           30.5            795             738
# 13           30.5            795             738
# 14           30.5            795             738
# 15           30.5            795             738

# %%
cropped_preview_results = preview_rotated_and_cropped(
    config_df=video_config_df,
    preview_time_fraction=preview_time_fraction,
)

cropped_preview_results
# Out:
# Crop previews:   0%|                                   | 0/16 [00:00<?, ?file/s]
# ### Rotation + crop preview: m752_01012025_18_25_40_concactenatedbehavCam00_behavCam17.mp4
# Angle: `30.5`
# Preview time: `143.39s`
# Crop box: `x=78, y=360, w=658, h=41`
# Crop previews:   6%|█▋                         | 1/16 [00:01<00:23,  1.55s/file]
# ### Rotation + crop preview: m752_01102024_16_18_25_concactenatedbehavCam00_behavCam17.mp4
# Angle: `30.5`
# Preview time: `143.40s`
# Crop box: `x=85, y=351, w=661, h=45`
# Crop previews:  12%|███▍                       | 2/16 [00:02<00:12,  1.08file/s]
# ### Rotation + crop preview: m752_02012025_19_56_52_concactenatedbehavCam00_behavCam17.mp4
# Angle: `30.5`
# Preview time: `143.45s`
# Crop box: `x=78, y=360, w=658, h=41`
# Crop previews:  19%|█████                      | 3/16 [00:02<00:09,  1.39file/s]
# ### Rotation + crop preview: m752_02102024_14_10_13_concactenatedbehavCam00_behavCam17.mp4
# Angle: `30.5`
# Preview time: `143.43s`
# Crop box: `x=85, y=351, w=662, h=46`
# Crop previews:  25%|██████▊                    | 4/16 [00:02<00:07,  1.60file/s]
# ### Rotation + crop preview: m752_03102024_13_18_31_concactenatedbehavCam00_behavCam17.mp4
# Angle: `30.5`
# Preview time: `143.38s`
# Crop box: `x=86, y=351, w=658, h=45`
# Crop previews:  31%|████████▍                  | 5/16 [00:03<00:06,  1.74file/s]
# ### Rotation + crop preview: m752_04012025_18_46_25_concactenatedbehavCam00_behavCam13.mp4
# Angle: `30.5`
# Preview time: `108.78s`
# Crop box: `x=78, y=360, w=658, h=41`
# Crop previews:  38%|██████████▏                | 6/16 [00:03<00:05,  1.84file/s]
# ### Rotation + crop preview: m752_04102024_15_56_54_concactenatedbehavCam00_behavCam17.mp4
# Angle: `30.5`
# Preview time: `143.35s`
# Crop box: `x=66, y=355, w=659, h=38`
# Crop previews:  44%|███████████▊               | 7/16 [00:04<00:04,  1.91file/s]
# ### Rotation + crop preview: m752_05012025_16_56_29_concactenatedbehavCam00_behavCam17.mp4
# Angle: `30.5`
# Preview time: `143.43s`
# Crop box: `x=78, y=360, w=658, h=41`
# Crop previews:  50%|█████████████▌             | 8/16 [00:04<00:04,  1.94file/s]
# ### Rotation + crop preview: m752_06012025_20_35_19_concactenatedbehavCam00_behavCam11.mp4
# Angle: `30.5`
# Preview time: `93.60s`
# Crop box: `x=78, y=360, w=658, h=41`
# Crop previews:  56%|███████████████▏           | 9/16 [00:05<00:03,  1.98file/s]
# ### Rotation + crop preview: m752_06012025_20_48_29_concactenatedbehavCam00_behavCam09.mp4
# Angle: `30.5`
# Preview time: `81.79s`
# Crop box: `x=78, y=360, w=658, h=41`
# Crop previews:  62%|████████████████▎         | 10/16 [00:05<00:02,  2.00file/s]
# ### Rotation + crop preview: m752_07012025_20_02_00_concactenatedbehavCam00_behavCam17.mp4
# Angle: `30.5`
# Preview time: `143.38s`
# Crop box: `x=78, y=360, w=658, h=41`
# Crop previews:  69%|█████████████████▉        | 11/16 [00:06<00:02,  2.01file/s]
# ### Rotation + crop preview: m752_08012025_17_12_33_concactenatedbehavCam00_behavCam17.mp4
# Angle: `30.5`
# Preview time: `143.38s`
# Crop box: `x=78, y=360, w=658, h=41`
# Crop previews:  75%|███████████████████▌      | 12/16 [00:06<00:01,  2.01file/s]
# ### Rotation + crop preview: m752_09012025_13_01_33_concactenatedbehavCam00_behavCam17.mp4
# Angle: `30.5`
# Preview time: `143.45s`
# Crop box: `x=78, y=360, w=658, h=41`
# Crop previews:  81%|█████████████████████▏    | 13/16 [00:07<00:01,  2.03file/s]
# ### Rotation + crop preview: m752_10012025_16_46_25_concactenatedbehavCam00_behavCam17.mp4
# Angle: `30.5`
# Preview time: `143.45s`
# Crop box: `x=78, y=360, w=658, h=41`
# Crop previews:  88%|██████████████████████▊   | 14/16 [00:07<00:00,  2.06file/s]
# ### Rotation + crop preview: m752_10102024_14_28_27_concactenatedbehavCam00_behavCam07.mp4
# Angle: `30.5`
# Preview time: `59.17s`
# Crop box: `x=69, y=354, w=657, h=39`
# Crop previews:  94%|████████████████████████▍ | 15/16 [00:08<00:00,  2.05file/s]
# ### Rotation + crop preview: m752_10102024_14_42_07_concactenatedbehavCam00_behavCam14.mp4
# Angle: `30.5`
# Preview time: `123.33s`
# Crop box: `x=66, y=355, w=661, h=37`
# Crop previews: 100%|██████████████████████████| 16/16 [00:08<00:00,  1.81file/s]
#                                             file_name  preview_time_sec  \
# 0   m752_01012025_18_25_40_concactenatedbehavCam00...        143.391667
# 1   m752_01102024_16_18_25_concactenatedbehavCam00...        143.400000
# 2   m752_02012025_19_56_52_concactenatedbehavCam00...        143.450000
# 3   m752_02102024_14_10_13_concactenatedbehavCam00...        143.433334
# 4   m752_03102024_13_18_31_concactenatedbehavCam00...        143.375000
# 5   m752_04012025_18_46_25_concactenatedbehavCam00...        108.783333
# 6   m752_04102024_15_56_54_concactenatedbehavCam00...        143.350000
# 7   m752_05012025_16_56_29_concactenatedbehavCam00...        143.433334
# 8   m752_06012025_20_35_19_concactenatedbehavCam00...         93.600000
# 9   m752_06012025_20_48_29_concactenatedbehavCam00...         81.791667
# 10  m752_07012025_20_02_00_concactenatedbehavCam00...        143.383333
# 11  m752_08012025_17_12_33_concactenatedbehavCam00...        143.383333
# 12  m752_09012025_13_01_33_concactenatedbehavCam00...        143.450000
# 13  m752_10012025_16_46_25_concactenatedbehavCam00...        143.450000
# 14  m752_10102024_14_28_27_concactenatedbehavCam00...         59.175000
# 15  m752_10102024_14_42_07_concactenatedbehavCam00...        123.333333
#
#     angle_degrees  crop_x  crop_y  crop_width  crop_height
# 0            30.5      78     360         658           41
# 1            30.5      85     351         661           45
# 2            30.5      78     360         658           41
# 3            30.5      85     351         662           46
# 4            30.5      86     351         658           45
# 5            30.5      78     360         658           41
# 6            30.5      66     355         659           38
# 7            30.5      78     360         658           41
# 8            30.5      78     360         658           41
# 9            30.5      78     360         658           41
# 10           30.5      78     360         658           41
# 11           30.5      78     360         658           41
# 12           30.5      78     360         658           41
# 13           30.5      78     360         658           41
# 14           30.5      69     354         657           39
# 15           30.5      66     355         661           37

# %%
rotation_batch_results = batch_rotate_from_config(
    config_df=video_config_df,
    rotated_output_dir=rotated_output_dir,
    overwrite=overwrite_existing,
)

rotation_batch_results
# Out:
# Rotate files:   0%|                                    | 0/16 [00:00<?, ?file/s]
# m752_01012025_18_25_40_concactenatedbehavCam00_behavCam17.mp4:   0%| | 0/286.783
# m752_01012025_18_25_40_concactenatedbehavCam00_behavCam17.mp4:   2%| | 6.55/286.
# m752_01012025_18_25_40_concactenatedbehavCam00_behavCam17.mp4:   5%| | 12.966667
# m752_01012025_18_25_40_concactenatedbehavCam00_behavCam17.mp4:   7%| | 19.4/286.
# m752_01012025_18_25_40_concactenatedbehavCam00_behavCam17.mp4:   9%| | 25.45/286
# m752_01012025_18_25_40_concactenatedbehavCam00_behavCam17.mp4:  11%| | 30.65/286
# m752_01012025_18_25_40_concactenatedbehavCam00_behavCam17.mp4:  13%|▏| 36.1/286.
# m752_01012025_18_25_40_concactenatedbehavCam00_behavCam17.mp4:  14%|▏| 39.35/286
# m752_01012025_18_25_40_concactenatedbehavCam00_behavCam17.mp4:  16%|▏| 44.7/286.
# m752_01012025_18_25_40_concactenatedbehavCam00_behavCam17.mp4:  18%|▏| 50.666667
# m752_01012025_18_25_40_concactenatedbehavCam00_behavCam17.mp4:  20%|▏| 56.233333
# m752_01012025_18_25_40_concactenatedbehavCam00_behavCam17.mp4:  21%|▏| 61.55/286
# m752_01012025_18_25_40_concactenatedbehavCam00_behavCam17.mp4:  23%|▏| 66.6/286.
# m752_01012025_18_25_40_concactenatedbehavCam00_behavCam17.mp4:  25%|▎| 72.7/286.
# m752_01012025_18_25_40_concactenatedbehavCam00_behavCam17.mp4:  27%|▎| 78.2/286.
# m752_01012025_18_25_40_concactenatedbehavCam00_behavCam17.mp4:  28%|▎| 81.433333
# m752_01012025_18_25_40_concactenatedbehavCam00_behavCam17.mp4:  30%|▎| 86.85/286
# m752_01012025_18_25_40_concactenatedbehavCam00_behavCam17.mp4:  32%|▎| 92.2/286.
# m752_01012025_18_25_40_concactenatedbehavCam00_behavCam17.mp4:  34%|▎| 97.9/286.
# m752_01012025_18_25_40_concactenatedbehavCam00_behavCam17.mp4:  36%|▎| 103.83333
# m752_01012025_18_25_40_concactenatedbehavCam00_behavCam17.mp4:  38%|▍| 109.18333
# m752_01012025_18_25_40_concactenatedbehavCam00_behavCam17.mp4:  40%|▍| 114.28333
# m752_01012025_18_25_40_concactenatedbehavCam00_behavCam17.mp4:  42%|▍| 119.95/28
# m752_01012025_18_25_40_concactenatedbehavCam00_behavCam17.mp4:  43%|▍| 123.6/286
# m752_01012025_18_25_40_concactenatedbehavCam00_behavCam17.mp4:  45%|▍| 129.08333
# m752_01012025_18_25_40_concactenatedbehavCam00_behavCam17.mp4:  47%|▍| 134.4/286
# m752_01012025_18_25_40_concactenatedbehavCam00_behavCam17.mp4:  49%|▍| 139.8/286
# m752_01012025_18_25_40_concactenatedbehavCam00_behavCam17.mp4:  51%|▌| 145.15/28
# m752_01012025_18_25_40_concactenatedbehavCam00_behavCam17.mp4:  53%|▌| 151.35/28
# m752_01012025_18_25_40_concactenatedbehavCam00_behavCam17.mp4:  55%|▌| 156.8/286
# m752_01012025_18_25_40_concactenatedbehavCam00_behavCam17.mp4:  57%|▌| 162.2/286
# m752_01012025_18_25_40_concactenatedbehavCam00_behavCam17.mp4:  58%|▌| 167.61666
# m752_01012025_18_25_40_concactenatedbehavCam00_behavCam17.mp4:  60%|▌| 173.5/286
# m752_01012025_18_25_40_concactenatedbehavCam00_behavCam17.mp4:  62%|▌| 179.13333
# m752_01012025_18_25_40_concactenatedbehavCam00_behavCam17.mp4:  64%|▋| 182.41666
# m752_01012025_18_25_40_concactenatedbehavCam00_behavCam17.mp4:  65%|▋| 187.53333
# m752_01012025_18_25_40_concactenatedbehavCam00_behavCam17.mp4:  67%|▋| 192.38333
# m752_01012025_18_25_40_concactenatedbehavCam00_behavCam17.mp4:  69%|▋| 198.01666
# m752_01012025_18_25_40_concactenatedbehavCam00_behavCam17.mp4:  71%|▋| 203.28333
# m752_01012025_18_25_40_concactenatedbehavCam00_behavCam17.mp4:  73%|▋| 208.73333
# m752_01012025_18_25_40_concactenatedbehavCam00_behavCam17.mp4:  75%|▋| 214.06666
# m752_01012025_18_25_40_concactenatedbehavCam00_behavCam17.mp4:  76%|▊| 217.6/286
# m752_01012025_18_25_40_concactenatedbehavCam00_behavCam17.mp4:  78%|▊| 223.33333
# m752_01012025_18_25_40_concactenatedbehavCam00_behavCam17.mp4:  80%|▊| 228.8/286
# m752_01012025_18_25_40_concactenatedbehavCam00_behavCam17.mp4:  82%|▊| 234.15/28
# m752_01012025_18_25_40_concactenatedbehavCam00_behavCam17.mp4:  84%|▊| 239.66666
# m752_01012025_18_25_40_concactenatedbehavCam00_behavCam17.mp4:  86%|▊| 245.68333
# m752_01012025_18_25_40_concactenatedbehavCam00_behavCam17.mp4:  88%|▉| 251.0/286
# m752_01012025_18_25_40_concactenatedbehavCam00_behavCam17.mp4:  89%|▉| 256.31666
# m752_01012025_18_25_40_concactenatedbehavCam00_behavCam17.mp4:  91%|▉| 261.66666
# m752_01012025_18_25_40_concactenatedbehavCam00_behavCam17.mp4:  93%|▉| 267.11666
# m752_01012025_18_25_40_concactenatedbehavCam00_behavCam17.mp4:  95%|▉| 272.5/286
# m752_01012025_18_25_40_concactenatedbehavCam00_behavCam17.mp4:  97%|▉| 277.85/28
# m752_01012025_18_25_40_concactenatedbehavCam00_behavCam17.mp4:  99%|▉| 283.78333
# m752_01012025_18_25_40_concactenatedbehavCam00_behavCam17.mp4: 100%|█| 286
# m752_10012025_16_46_25_concactenatedbehavCam00_behavCam17_rotated.avi:  32%|▎| 9
# m752_10012025_16_46_25_concactenatedbehavCam00_behavCam17_rotated.avi:  34%|▎| 9
# m752_10012025_16_46_25_concactenatedbehavCam00_behavCam17_rotated.avi:  36%|▎| 1
# m752_10012025_16_46_25_concactenatedbehavCam00_behavCam17_rotated.avi:  39%|▍| 1
# m752_10012025_16_46_25_concactenatedbehavCam00_behavCam17_rotated.avi:  41%|▍| 1
# m752_10012025_16_46_25_concactenatedbehavCam00_behavCam17_rotated.avi:  43%|▍| 1
# m752_10012025_16_46_25_concactenatedbehavCam00_behavCam17_rotated.avi:  46%|▍| 1
# m752_10012025_16_46_25_concactenatedbehavCam00_behavCam17_rotated.avi:  49%|▍| 1
# m752_10012025_16_46_25_concactenatedbehavCam00_behavCam17_rotated.avi:  51%|▌| 1
# m752_10012025_16_46_25_concactenatedbehavCam00_behavCam17_rotated.avi:  53%|▌| 1
# m752_10012025_16_46_25_concactenatedbehavCam00_behavCam17_rotated.avi:  56%|▌| 1
# m752_10012025_16_46_25_concactenatedbehavCam00_behavCam17_rotated.avi:  59%|▌| 1
# m752_10012025_16_46_25_concactenatedbehavCam00_behavCam17_rotated.avi:  61%|▌| 1
# m752_10012025_16_46_25_concactenatedbehavCam00_behavCam17_rotated.avi:  63%|▋| 1
# m752_10012025_16_46_25_concactenatedbehavCam00_behavCam17_rotated.avi:  66%|▋| 1
# m752_10012025_16_46_25_concactenatedbehavCam00_behavCam17_rotated.avi:  68%|▋| 1
# m752_10012025_16_46_25_concactenatedbehavCam00_behavCam17_rotated.avi:  70%|▋| 2
# m752_10012025_16_46_25_concactenatedbehavCam00_behavCam17_rotated.avi:  73%|▋| 2
# m752_10012025_16_46_25_concactenatedbehavCam00_behavCam17_rotated.avi:  76%|▊| 2
# m752_10012025_16_46_25_concactenatedbehavCam00_behavCam17_rotated.avi:  78%|▊| 2
# m752_10012025_16_46_25_concactenatedbehavCam00_behavCam17_rotated.avi:  80%|▊| 2
# m752_10012025_16_46_25_concactenatedbehavCam00_behavCam17_rotated.avi:  83%|▊| 2
# m752_10012025_16_46_25_concactenatedbehavCam00_behavCam17_rotated.avi:  86%|▊| 2
# m752_10012025_16_46_25_concactenatedbehavCam00_behavCam17_rotated.avi:  88%|▉| 2
# m752_10012025_16_46_25_concactenatedbehavCam00_behavCam17_rotated.avi:  90%|▉| 2
# m752_10012025_16_46_25_concactenatedbehavCam00_behavCam17_rotated.avi:  93%|▉| 2
# m752_10012025_16_46_25_concactenatedbehavCam00_behavCam17_rotated.avi:  96%|▉| 2
# m752_10012025_16_46_25_concactenatedbehavCam00_behavCam17_rotated.avi:  98%|▉| 2
# m752_10012025_16_46_25_concactenatedbehavCam00_behavCam17_rotated.avi: 100%|█| 2
# Crop files:  88%|█████████████████████████▍   | 14/16 [04:34<00:40, 20.01s/file]
# m752_10102024_14_28_27_concactenatedbehavCam00_behavCam07_rotated.avi:   0%| | 0
# m752_10102024_14_28_27_concactenatedbehavCam00_behavCam07_rotated.avi:   5%| | 6
# m752_10102024_14_28_27_concactenatedbehavCam00_behavCam07_rotated.avi:  10%| | 1
# m752_10102024_14_28_27_concactenatedbehavCam00_behavCam07_rotated.avi:  15%|▏| 1
# m752_10102024_14_28_27_concactenatedbehavCam00_behavCam07_rotated.avi:  22%|▏| 2
# m752_10102024_14_28_27_concactenatedbehavCam00_behavCam07_rotated.avi:  29%|▎| 3
# m752_10102024_14_28_27_concactenatedbehavCam00_behavCam07_rotated.avi:  34%|▎| 3
# m752_10102024_14_28_27_concactenatedbehavCam00_behavCam07_rotated.avi:  39%|▍| 4
# m752_10102024_14_28_27_concactenatedbehavCam00_behavCam07_rotated.avi:  45%|▍| 5
# m752_10102024_14_28_27_concactenatedbehavCam00_behavCam07_rotated.avi:  52%|▌| 6
# m752_10102024_14_28_27_concactenatedbehavCam00_behavCam07_rotated.avi:  57%|▌| 6
# m752_10102024_14_28_27_concactenatedbehavCam00_behavCam07_rotated.avi:  62%|▌| 7
# m752_10102024_14_28_27_concactenatedbehavCam00_behavCam07_rotated.avi:  69%|▋| 8
# m752_10102024_14_28_27_concactenatedbehavCam00_behavCam07_rotated.avi:  75%|▊| 8
# m752_10102024_14_28_27_concactenatedbehavCam00_behavCam07_rotated.avi:  79%|▊| 9
# m752_10102024_14_28_27_concactenatedbehavCam00_behavCam07_rotated.avi:  85%|▊| 1
# m752_10102024_14_28_27_concactenatedbehavCam00_behavCam07_rotated.avi:  93%|▉| 1
# m752_10102024_14_28_27_concactenatedbehavCam00_behavCam07_rotated.avi: 100%|▉| 1
# Crop files:  94%|███████████████████████████▏ | 15/16 [04:44<00:16, 16.78s/file]
# m752_10102024_14_42_07_concactenatedbehavCam00_behavCam14_rotated.avi:   0%| | 0
# m752_10102024_14_42_07_concactenatedbehavCam00_behavCam14_rotated.avi:   3%| | 6
# m752_10102024_14_42_07_concactenatedbehavCam00_behavCam14_rotated.avi:   5%| | 1
# m752_10102024_14_42_07_concactenatedbehavCam00_behavCam14_rotated.avi:   7%| | 1
# m752_10102024_14_42_07_concactenatedbehavCam00_behavCam14_rotated.avi:  10%| | 2
# m752_10102024_14_42_07_concactenatedbehavCam00_behavCam14_rotated.avi:  14%|▏| 3
# m752_10102024_14_42_07_concactenatedbehavCam00_behavCam14_rotated.avi:  16%|▏| 3
# m752_10102024_14_42_07_concactenatedbehavCam00_behavCam14_rotated.avi:  18%|▏| 4
# m752_10102024_14_42_07_concactenatedbehavCam00_behavCam14_rotated.avi:  22%|▏| 5
# m752_10102024_14_42_07_concactenatedbehavCam00_behavCam14_rotated.avi:  25%|▏| 6
# m752_10102024_14_42_07_concactenatedbehavCam00_behavCam14_rotated.avi:  27%|▎| 6
# m752_10102024_14_42_07_concactenatedbehavCam00_behavCam14_rotated.avi:  29%|▎| 7
# m752_10102024_14_42_07_concactenatedbehavCam00_behavCam14_rotated.avi:  33%|▎| 8
# m752_10102024_14_42_07_concactenatedbehavCam00_behavCam14_rotated.avi:  36%|▎| 8
# m752_10102024_14_42_07_concactenatedbehavCam00_behavCam14_rotated.avi:  38%|▍| 9
# m752_10102024_14_42_07_concactenatedbehavCam00_behavCam14_rotated.avi:  40%|▍| 9
# m752_10102024_14_42_07_concactenatedbehavCam00_behavCam14_rotated.avi:  44%|▍| 1
# m752_10102024_14_42_07_concactenatedbehavCam00_behavCam14_rotated.avi:  47%|▍| 1
# m752_10102024_14_42_07_concactenatedbehavCam00_behavCam14_rotated.avi:  49%|▍| 1
# m752_10102024_14_42_07_concactenatedbehavCam00_behavCam14_rotated.avi:  52%|▌| 1
# m752_10102024_14_42_07_concactenatedbehavCam00_behavCam14_rotated.avi:  56%|▌| 1
# m752_10102024_14_42_07_concactenatedbehavCam00_behavCam14_rotated.avi:  58%|▌| 1
# m752_10102024_14_42_07_concactenatedbehavCam00_behavCam14_rotated.avi:  60%|▌| 1
# m752_10102024_14_42_07_concactenatedbehavCam00_behavCam14_rotated.avi:  63%|▋| 1
# m752_10102024_14_42_07_concactenatedbehavCam00_behavCam14_rotated.avi:  67%|▋| 1
# m752_10102024_14_42_07_concactenatedbehavCam00_behavCam14_rotated.avi:  69%|▋| 1
# m752_10102024_14_42_07_concactenatedbehavCam00_behavCam14_rotated.avi:  71%|▋| 1
# m752_10102024_14_42_07_concactenatedbehavCam00_behavCam14_rotated.avi:  75%|▋| 1
# m752_10102024_14_42_07_concactenatedbehavCam00_behavCam14_rotated.avi:  78%|▊| 1
# m752_10102024_14_42_07_concactenatedbehavCam00_behavCam14_rotated.avi:  80%|▊| 1
# m752_10102024_14_42_07_concactenatedbehavCam00_behavCam14_rotated.avi:  82%|▊| 2
# m752_10102024_14_42_07_concactenatedbehavCam00_behavCam14_rotated.avi:  86%|▊| 2
# m752_10102024_14_42_07_concactenatedbehavCam00_behavCam14_rotated.avi:  89%|▉| 2
# m752_10102024_14_42_07_concactenatedbehavCam00_behavCam14_rotated.avi:  91%|▉| 2
# m752_10102024_14_42_07_concactenatedbehavCam00_behavCam14_rotated.avi:  94%|▉| 2
# m752_10102024_14_42_07_concactenatedbehavCam00_behavCam14_rotated.avi:  97%|▉| 2
# m752_10102024_14_42_07_concactenatedbehavCam00_behavCam14_rotated.avi: 100%|█| 2
# Crop files: 100%|█████████████████████████████| 16/16 [05:02<00:00, 18.94s/file]
#                                            input_file  \
# 0   /Volumes/fsmresfiles/Basic_Sciences/Phys/Contr...
# 1   /Volumes/fsmresfiles/Basic_Sciences/Phys/Contr...
# 2   /Volumes/fsmresfiles/Basic_Sciences/Phys/Contr...
# 3   /Volumes/fsmresfiles/Basic_Sciences/Phys/Contr...
# 4   /Volumes/fsmresfiles/Basic_Sciences/Phys/Contr...
# 5   /Volumes/fsmresfiles/Basic_Sciences/Phys/Contr...
# 6   /Volumes/fsmresfiles/Basic_Sciences/Phys/Contr...
# 7   /Volumes/fsmresfiles/Basic_Sciences/Phys/Contr...
# 8   /Volumes/fsmresfiles/Basic_Sciences/Phys/Contr...
# 9   /Volumes/fsmresfiles/Basic_Sciences/Phys/Contr...
# 10  /Volumes/fsmresfiles/Basic_Sciences/Phys/Contr...
# 11  /Volumes/fsmresfiles/Basic_Sciences/Phys/Contr...
# 12  /Volumes/fsmresfiles/Basic_Sciences/Phys/Contr...
# 13  /Volumes/fsmresfiles/Basic_Sciences/Phys/Contr...
# 14  /Volumes/fsmresfiles/Basic_Sciences/Phys/Contr...
# 15  /Volumes/fsmresfiles/Basic_Sciences/Phys/Contr...
#
#                                           output_file  duration_sec  \
# 0   /Volumes/fsmresfiles/Basic_Sciences/Phys/Contr...    286.783333
# 1   /Volumes/fsmresfiles/Basic_Sciences/Phys/Contr...    286.800000
# 2   /Volumes/fsmresfiles/Basic_Sciences/Phys/Contr...    286.900000
# 3   /Volumes/fsmresfiles/Basic_Sciences/Phys/Contr...    286.866667
# 4   /Volumes/fsmresfiles/Basic_Sciences/Phys/Contr...    286.750000
# 5   /Volumes/fsmresfiles/Basic_Sciences/Phys/Contr...    217.566667
# 6   /Volumes/fsmresfiles/Basic_Sciences/Phys/Contr...    286.700000
# 7   /Volumes/fsmresfiles/Basic_Sciences/Phys/Contr...    286.866667
# 8   /Volumes/fsmresfiles/Basic_Sciences/Phys/Contr...    187.200000
# 9   /Volumes/fsmresfiles/Basic_Sciences/Phys/Contr...    163.583333
# 10  /Volumes/fsmresfiles/Basic_Sciences/Phys/Contr...    286.766667
# 11  /Volumes/fsmresfiles/Basic_Sciences/Phys/Contr...    286.766667
# 12  /Volumes/fsmresfiles/Basic_Sciences/Phys/Contr...    286.900000
# 13  /Volumes/fsmresfiles/Basic_Sciences/Phys/Contr...    286.900000
# 14  /Volumes/fsmresfiles/Basic_Sciences/Phys/Contr...    118.350000
# 15  /Volumes/fsmresfiles/Basic_Sciences/Phys/Contr...    246.666667
#
#    input_codec  crop_x  crop_y  crop_width  crop_height  \
# 0        mjpeg      78     360         658           41
# 1        mjpeg      85     351         661           45
# 2        mjpeg      78     360         658           41
# 3        mjpeg      85     351         662           46
# 4        mjpeg      86     351         658           45
# 5        mjpeg      78     360         658           41
# 6        mjpeg      66     355         659           38
# 7        mjpeg      78     360         658           41
# 8        mjpeg      78     360         658           41
# 9        mjpeg      78     360         658           41
# 10       mjpeg      78     360         658           41
# 11       mjpeg      78     360         658           41
# 12       mjpeg      78     360         658           41
# 13       mjpeg      78     360         658           41
# 14       mjpeg      69     354         657           39
# 15       mjpeg      66     355         661           37
#
#                                     source_input_file  \
# 0   /Volumes/fsmresfiles/Basic_Sciences/Phys/Contr...
# 1   /Volumes/fsmresfiles/Basic_Sciences/Phys/Contr...
# 2   /Volumes/fsmresfiles/Basic_Sciences/Phys/Contr...
# 3   /Volumes/fsmresfiles/Basic_Sciences/Phys/Contr...
# 4   /Volumes/fsmresfiles/Basic_Sciences/Phys/Contr...
# 5   /Volumes/fsmresfiles/Basic_Sciences/Phys/Contr...
# 6   /Volumes/fsmresfiles/Basic_Sciences/Phys/Contr...
# 7   /Volumes/fsmresfiles/Basic_Sciences/Phys/Contr...
# 8   /Volumes/fsmresfiles/Basic_Sciences/Phys/Contr...
# 9   /Volumes/fsmresfiles/Basic_Sciences/Phys/Contr...
# 10  /Volumes/fsmresfiles/Basic_Sciences/Phys/Contr...
# 11  /Volumes/fsmresfiles/Basic_Sciences/Phys/Contr...
# 12  /Volumes/fsmresfiles/Basic_Sciences/Phys/Contr...
# 13  /Volumes/fsmresfiles/Basic_Sciences/Phys/Contr...
# 14  /Volumes/fsmresfiles/Basic_Sciences/Phys/Contr...
# 15  /Volumes/fsmresfiles/Basic_Sciences/Phys/Contr...
#
#                                    rotated_input_file     status
# 0   /Volumes/fsmresfiles/Basic_Sciences/Phys/Contr...  processed
# 1   /Volumes/fsmresfiles/Basic_Sciences/Phys/Contr...  processed
# 2   /Volumes/fsmresfiles/Basic_Sciences/Phys/Contr...  processed
# 3   /Volumes/fsmresfiles/Basic_Sciences/Phys/Contr...  processed
# 4   /Volumes/fsmresfiles/Basic_Sciences/Phys/Contr...  processed
# 5   /Volumes/fsmresfiles/Basic_Sciences/Phys/Contr...  processed
# 6   /Volumes/fsmresfiles/Basic_Sciences/Phys/Contr...  processed
# 7   /Volumes/fsmresfiles/Basic_Sciences/Phys/Contr...  processed
# 8   /Volumes/fsmresfiles/Basic_Sciences/Phys/Contr...  processed
# 9   /Volumes/fsmresfiles/Basic_Sciences/Phys/Contr...  processed
# 10  /Volumes/fsmresfiles/Basic_Sciences/Phys/Contr...  processed
# 11  /Volumes/fsmresfiles/Basic_Sciences/Phys/Contr...  processed
# 12  /Volumes/fsmresfiles/Basic_Sciences/Phys/Contr...  processed
# 13  /Volumes/fsmresfiles/Basic_Sciences/Phys/Contr...  processed
# 14  /Volumes/fsmresfiles/Basic_Sciences/Phys/Contr...  processed
# 15  /Volumes/fsmresfiles/Basic_Sciences/Phys/Contr...  processed
