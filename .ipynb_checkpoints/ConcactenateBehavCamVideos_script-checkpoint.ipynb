# %%
from pathlib import Path
import pandas as pd
import glob
import os 
import cv2
from tqdm import tqdm
import re

# %%
base = Path(r"/Volumes/fsmresfiles/Basic_Sciences/Phys/ContractorLab/Projects/YZ/Miniscope_data/Miniscope_data/Linear_track/")
mouse_num = "388"

# Equivalent to: */994*/My_WebCam/*.avi
avi_matches = sorted(base.glob(f"*/{mouse_num}*/My_WebCam/*.avi"))

# Get unique My_WebCam folders that actually contain AVI files
webcam_dirs = sorted({p.parent for p in avi_matches})

print(f"Found {len(webcam_dirs)} My_WebCam folders for mouse {mouse_num}:")
for d in webcam_dirs:
    print(d)
def natural_key(path):
    """
    Sorts 0.avi, 1.avi, 2.avi, ..., 10.avi correctly.
    Also works for behavCam00.avi, behavCam01.avi, etc.
    """
    return [
        int(text) if text.isdigit() else text.lower()
        for text in re.split(r"(\d+)", path.name)
    ]
rows = []
for d in webcam_dirs:
    avi_files = sorted(d.glob("*.avi"), key=natural_key)
    mp4_files = sorted(d.glob("*.mp4"), key=natural_key)
    csv_files = sorted(d.glob("*.csv"), key=natural_key)
    concat_files = sorted(d.glob("*concactenated*.mp4"), key=natural_key)
    rows.append({
        "date_folder": d.parent.parent.name,
        "session_folder": d.parent.name,
        "My_WebCam_path": str(d),
        "n_avi": len(avi_files),
        "n_mp4": len(mp4_files),
        "n_csv": len(csv_files),
        "n_concactenated": len(concat_files),
        "first_avi": avi_files[0].name if avi_files else None,
        "last_avi": avi_files[-1].name if avi_files else None,
        "concactenated_file": concat_files[0].name if concat_files else None,
    })
webcam_summary = pd.DataFrame(rows)
webcam_summary
# Out:
# Found 13 My_WebCam folders for mouse 388:
# /Volumes/fsmresfiles/Basic_Sciences/Phys/ContractorLab/Projects/YZ/Miniscope_data/Miniscope_data/Linear_track/2025_07_01_test/388_14_29_09/My_WebCam
# /Volumes/fsmresfiles/Basic_Sciences/Phys/ContractorLab/Projects/YZ/Miniscope_data/Miniscope_data/Linear_track/2025_07_01_test/388_14_37_41/My_WebCam
# /Volumes/fsmresfiles/Basic_Sciences/Phys/ContractorLab/Projects/YZ/Miniscope_data/Miniscope_data/Linear_track/2025_07_01_test/388_14_49_45/My_WebCam
# /Volumes/fsmresfiles/Basic_Sciences/Phys/ContractorLab/Projects/YZ/Miniscope_data/Miniscope_data/Linear_track/2025_07_02/388_14_48_02/My_WebCam
# /Volumes/fsmresfiles/Basic_Sciences/Phys/ContractorLab/Projects/YZ/Miniscope_data/Miniscope_data/Linear_track/2025_07_03/388_14_28_38/My_WebCam
# /Volumes/fsmresfiles/Basic_Sciences/Phys/ContractorLab/Projects/YZ/Miniscope_data/Miniscope_data/Linear_track/2025_07_04/388_15_43_20/My_WebCam
# /Volumes/fsmresfiles/Basic_Sciences/Phys/ContractorLab/Projects/YZ/Miniscope_data/Miniscope_data/Linear_track/2025_07_05/388_16_21_10/My_WebCam
# /Volumes/fsmresfiles/Basic_Sciences/Phys/ContractorLab/Projects/YZ/Miniscope_data/Miniscope_data/Linear_track/2025_07_06/388_14_53_04/My_WebCam
# /Volumes/fsmresfiles/Basic_Sciences/Phys/ContractorLab/Projects/YZ/Miniscope_data/Miniscope_data/Linear_track/2025_07_07/388_11_39_31/My_WebCam
# /Volumes/fsmresfiles/Basic_Sciences/Phys/ContractorLab/Projects/YZ/Miniscope_data/Miniscope_data/Linear_track/2025_07_08/388_13_48_35/My_WebCam
# /Volumes/fsmresfiles/Basic_Sciences/Phys/ContractorLab/Projects/YZ/Miniscope_data/Miniscope_data/Linear_track/2025_07_09/388_11_51_21/My_WebCam
# /Volumes/fsmresfiles/Basic_Sciences/Phys/ContractorLab/Projects/YZ/Miniscope_data/Miniscope_data/Linear_track/2025_07_10/388_14_00_39/My_WebCam
# /Volumes/fsmresfiles/Basic_Sciences/Phys/ContractorLab/Projects/YZ/Miniscope_data/Miniscope_data/Linear_track/2025_07_11/388_14_35_14/My_WebCam
#         date_folder session_folder  \
# 0   2025_07_01_test   388_14_29_09
# 1   2025_07_01_test   388_14_37_41
# 2   2025_07_01_test   388_14_49_45
# 3        2025_07_02   388_14_48_02
# 4        2025_07_03   388_14_28_38
# 5        2025_07_04   388_15_43_20
# 6        2025_07_05   388_16_21_10
# 7        2025_07_06   388_14_53_04
# 8        2025_07_07   388_11_39_31
# 9        2025_07_08   388_13_48_35
# 10       2025_07_09   388_11_51_21
# 11       2025_07_10   388_14_00_39
# 12       2025_07_11   388_14_35_14
#
#                                        My_WebCam_path  n_avi  n_mp4  n_csv  \
# 0   /Volumes/fsmresfiles/Basic_Sciences/Phys/Contr...      4      0      1
# 1   /Volumes/fsmresfiles/Basic_Sciences/Phys/Contr...      4      0      1
# 2   /Volumes/fsmresfiles/Basic_Sciences/Phys/Contr...      4      0      1
# 3   /Volumes/fsmresfiles/Basic_Sciences/Phys/Contr...     21      0      1
# 4   /Volumes/fsmresfiles/Basic_Sciences/Phys/Contr...     21      0      1
# 5   /Volumes/fsmresfiles/Basic_Sciences/Phys/Contr...     21      0      1
# 6   /Volumes/fsmresfiles/Basic_Sciences/Phys/Contr...     21      0      1
# 7   /Volumes/fsmresfiles/Basic_Sciences/Phys/Contr...     21      0      1
# 8   /Volumes/fsmresfiles/Basic_Sciences/Phys/Contr...     21      0      1
# 9   /Volumes/fsmresfiles/Basic_Sciences/Phys/Contr...     21      0      1
# 10  /Volumes/fsmresfiles/Basic_Sciences/Phys/Contr...     21      0      1
# 11  /Volumes/fsmresfiles/Basic_Sciences/Phys/Contr...     21      0      1
# 12  /Volumes/fsmresfiles/Basic_Sciences/Phys/Contr...     21      0      1
#
#     n_concactenated first_avi last_avi concactenated_file
# 0                 0     0.avi    3.avi               None
# 1                 0     0.avi    3.avi               None
# 2                 0     0.avi    3.avi               None
# 3                 0     0.avi   20.avi               None
# 4                 0     0.avi   20.avi               None
# 5                 0     0.avi   20.avi               None
# 6                 0     0.avi   20.avi               None
# 7                 0     0.avi   20.avi               None
# 8                 0     0.avi   20.avi               None
# 9                 0     0.avi   20.avi               None
# 10                0     0.avi   20.avi               None
# 11                0     0.avi   20.avi               None
# 12                0     0.avi   20.avi               None

# %%
mouse_num = "388"

def natural_key(path):
    """
    Sorts:
        0.avi, 1.avi, 2.avi, ..., 10.avi
    and:
        behavCam00.avi, behavCam01.avi, ..., behavCam10.avi
    in numerical order.
    """
    path = Path(path)
    return [
        int(text) if text.isdigit() else text.lower()
        for text in re.split(r"(\d+)", path.name)
    ]


def normalize_avi_names(session_path):
    """
    Rename:
        0.avi              -> behavCam00.avi
        1.avi              -> behavCam01.avi
        behavCam0.avi      -> behavCam00.avi
        behavCam00.avi     -> unchanged
    """
    session_path = Path(session_path)

    avi_files = sorted(session_path.glob("*.avi"), key=natural_key)

    for video_f in avi_files:
        stem = video_f.stem  # safer than strip(".avi")

        if stem.startswith("behavCam"):
            num_part = stem.replace("behavCam", "")
        else:
            num_part = stem

        if not num_part.isdigit():
            print(f"Skipping rename for unexpected AVI name: {video_f.name}")
            continue

        reformatted_name = f"behavCam{int(num_part):02d}.avi"
        reformatted_path = video_f.with_name(reformatted_name)

        if video_f.name == reformatted_name:
            continue

        if reformatted_path.exists():
            print(f"Target already exists, not renaming: {video_f.name} -> {reformatted_name}")
            continue

        print(f"Renaming: {video_f.name} -> {reformatted_name}")
        video_f.rename(reformatted_path)


def make_session_name(date_folder, session_folder, mouse_num):
    """
    Example:
        date_folder    = 2024_12_30
        session_folder = 994_18_25_08

    Output:
        m994_30122024_18_25_08
    """
    date_folder = str(date_folder)
    session_folder = str(session_folder)

    m = re.search(r"(\d{4})_(\d{2})_(\d{2})", date_folder)
    if m is None:
        raise ValueError(f"Could not parse YYYY_MM_DD from date_folder: {date_folder}")

    yyyy, mm, dd = m.groups()
    ddmmyyyy = f"{dd}{mm}{yyyy}"

    session_parts = session_folder.split("_")
    if len(session_parts) < 4:
        raise ValueError(f"Unexpected session_folder format: {session_folder}")

    time_part = "_".join(session_parts[1:])

    return f"m{mouse_num}_{ddmmyyyy}_{time_part}"



def concatenate_session_avis(session_path, session_to_concat, overwrite=False):
    session_path = Path(session_path)

    normalize_avi_names(session_path)

    videos = sorted(session_path.glob("*.avi"), key=natural_key)

    if len(videos) == 0:
        print(f"No AVI files found in: {session_path}")
        return None

    first_stem = videos[0].stem
    last_stem = videos[-1].stem

    output_path = session_path / f"{session_to_concat}_concactenated{first_stem}_{last_stem}.mp4"

    if output_path.exists() and not overwrite:
        print(f"Output already exists, skipping: {output_path.name}")
        return output_path

    vcap = cv2.VideoCapture(str(videos[0]))

    if not vcap.isOpened():
        print(f"Could not open first video: {videos[0]}")
        return None

    width = int(vcap.get(cv2.CAP_PROP_FRAME_WIDTH))
    height = int(vcap.get(cv2.CAP_PROP_FRAME_HEIGHT))
    fps = vcap.get(cv2.CAP_PROP_FPS)
    vcap.release()

    if fps is None or fps <= 0:
        print(f"Bad FPS detected for {videos[0]}, using fps=30")
        fps = 30

    print("")
    print(f"Concatenating session: {session_to_concat}")
    print(f"Folder: {session_path}")
    print(f"Number of AVI files: {len(videos)}")
    print(f"Output: {output_path.name}")
    print(f"Width x Height: {width} x {height}, FPS: {fps}")

    fourcc = cv2.VideoWriter_fourcc(*"mp4v")
    video_writer = cv2.VideoWriter(
        str(output_path),
        fourcc,
        fps,
        (width, height)
    )

    if not video_writer.isOpened():
        print(f"Could not create output video: {output_path}")
        return None

    for v in tqdm(videos, desc=session_to_concat):
        curr_v = cv2.VideoCapture(str(v))

        if not curr_v.isOpened():
            print(f"Could not open video, skipping: {v}")
            continue

        while True:
            r, frame = curr_v.read()

            if not r:
                break

            video_writer.write(frame)

        curr_v.release()

    video_writer.release()

    print(f"Finished: {output_path}")
    return output_path

# %%
outputs = []

for idx, row in webcam_summary.iterrows():
    session_path = Path(row["My_WebCam_path"])
    date_folder = row["date_folder"]
    session_folder = row["session_folder"]

    session_to_concat = make_session_name(
        date_folder=date_folder,
        session_folder=session_folder,
        mouse_num=mouse_num
    )

    output_path = concatenate_session_avis(
        session_path=session_path,
        session_to_concat=session_to_concat,
        overwrite=False
    )

    outputs.append({
        "date_folder": date_folder,
        "session_folder": session_folder,
        "My_WebCam_path": str(session_path),
        "output_path": str(output_path) if output_path is not None else None,
    })

concat_results = pd.DataFrame(outputs)

concat_results
# Out:
# Renaming: 0.avi -> behavCam00.avi
# Renaming: 1.avi -> behavCam01.avi
# Renaming: 2.avi -> behavCam02.avi
# Renaming: 3.avi -> behavCam03.avi
#
# Concatenating session: m388_01072025_14_29_09
# Folder: /Volumes/fsmresfiles/Basic_Sciences/Phys/ContractorLab/Projects/YZ/Miniscope_data/Miniscope_data/Linear_track/2025_07_01_test/388_14_29_09/My_WebCam
# Number of AVI files: 4
# Output: m388_01072025_14_29_09_concactenatedbehavCam00_behavCam03.mp4
# Width x Height: 640 x 480, FPS: 60.0
# m388_01072025_14_29_09: 100%|█████████████████████| 4/4 [00:06<00:00,  1.61s/it]
# Finished: /Volumes/fsmresfiles/Basic_Sciences/Phys/ContractorLab/Projects/YZ/Miniscope_data/Miniscope_data/Linear_track/2025_07_01_test/388_14_29_09/My_WebCam/m388_01072025_14_29_09_concactenatedbehavCam00_behavCam03.mp4
# Renaming: 0.avi -> behavCam00.avi
# Renaming: 1.avi -> behavCam01.avi
# Renaming: 2.avi -> behavCam02.avi
# Renaming: 3.avi -> behavCam03.avi
#
# Concatenating session: m388_01072025_14_37_41
# Folder: /Volumes/fsmresfiles/Basic_Sciences/Phys/ContractorLab/Projects/YZ/Miniscope_data/Miniscope_data/Linear_track/2025_07_01_test/388_14_37_41/My_WebCam
# Number of AVI files: 4
# Output: m388_01072025_14_37_41_concactenatedbehavCam00_behavCam03.mp4
# Width x Height: 640 x 480, FPS: 60.0
# m388_01072025_14_37_41: 100%|█████████████████████| 4/4 [00:06<00:00,  1.60s/it]
# Finished: /Volumes/fsmresfiles/Basic_Sciences/Phys/ContractorLab/Projects/YZ/Miniscope_data/Miniscope_data/Linear_track/2025_07_01_test/388_14_37_41/My_WebCam/m388_01072025_14_37_41_concactenatedbehavCam00_behavCam03.mp4
# Renaming: 0.avi -> behavCam00.avi
# Renaming: 1.avi -> behavCam01.avi
# Renaming: 2.avi -> behavCam02.avi
# Renaming: 3.avi -> behavCam03.avi
#
# Concatenating session: m388_01072025_14_49_45
# Folder: /Volumes/fsmresfiles/Basic_Sciences/Phys/ContractorLab/Projects/YZ/Miniscope_data/Miniscope_data/Linear_track/2025_07_01_test/388_14_49_45/My_WebCam
# Number of AVI files: 4
# Output: m388_01072025_14_49_45_concactenatedbehavCam00_behavCam03.mp4
# Width x Height: 640 x 480, FPS: 60.0
# m388_01072025_14_49_45: 100%|█████████████████████| 4/4 [00:06<00:00,  1.60s/it]
# Finished: /Volumes/fsmresfiles/Basic_Sciences/Phys/ContractorLab/Projects/YZ/Miniscope_data/Miniscope_data/Linear_track/2025_07_01_test/388_14_49_45/My_WebCam/m388_01072025_14_49_45_concactenatedbehavCam00_behavCam03.mp4
# Renaming: 0.avi -> behavCam00.avi
# Renaming: 1.avi -> behavCam01.avi
# Renaming: 2.avi -> behavCam02.avi
# Renaming: 3.avi -> behavCam03.avi
# Renaming: 4.avi -> behavCam04.avi
# Renaming: 5.avi -> behavCam05.avi
# Renaming: 6.avi -> behavCam06.avi
# Renaming: 7.avi -> behavCam07.avi
# Renaming: 8.avi -> behavCam08.avi
# Renaming: 9.avi -> behavCam09.avi
# Renaming: 10.avi -> behavCam10.avi
# Renaming: 11.avi -> behavCam11.avi
# Renaming: 12.avi -> behavCam12.avi
# Renaming: 13.avi -> behavCam13.avi
# Renaming: 14.avi -> behavCam14.avi
# Renaming: 15.avi -> behavCam15.avi
# Renaming: 16.avi -> behavCam16.avi
# Renaming: 17.avi -> behavCam17.avi
# Renaming: 18.avi -> behavCam18.avi
# Renaming: 19.avi -> behavCam19.avi
# Renaming: 20.avi -> behavCam20.avi
#
# Concatenating session: m388_02072025_14_48_02
# Folder: /Volumes/fsmresfiles/Basic_Sciences/Phys/ContractorLab/Projects/YZ/Miniscope_data/Miniscope_data/Linear_track/2025_07_02/388_14_48_02/My_WebCam
# Number of AVI files: 21
# Output: m388_02072025_14_48_02_concactenatedbehavCam00_behavCam20.mp4
# Width x Height: 640 x 480, FPS: 60.0
# m388_02072025_14_48_02: 100%|███████████████████| 21/21 [00:43<00:00,  2.09s/it]
# Finished: /Volumes/fsmresfiles/Basic_Sciences/Phys/ContractorLab/Projects/YZ/Miniscope_data/Miniscope_data/Linear_track/2025_07_02/388_14_48_02/My_WebCam/m388_02072025_14_48_02_concactenatedbehavCam00_behavCam20.mp4
# Renaming: 0.avi -> behavCam00.avi
# Renaming: 1.avi -> behavCam01.avi
# Renaming: 2.avi -> behavCam02.avi
# Renaming: 3.avi -> behavCam03.avi
# Renaming: 4.avi -> behavCam04.avi
# Renaming: 5.avi -> behavCam05.avi
# Renaming: 6.avi -> behavCam06.avi
# Renaming: 7.avi -> behavCam07.avi
# Renaming: 8.avi -> behavCam08.avi
# Renaming: 9.avi -> behavCam09.avi
# Renaming: 10.avi -> behavCam10.avi
# Renaming: 11.avi -> behavCam11.avi
# Renaming: 12.avi -> behavCam12.avi
# Renaming: 13.avi -> behavCam13.avi
# Renaming: 14.avi -> behavCam14.avi
# Renaming: 15.avi -> behavCam15.avi
# Renaming: 16.avi -> behavCam16.avi
# Renaming: 17.avi -> behavCam17.avi
# Renaming: 18.avi -> behavCam18.avi
# Renaming: 19.avi -> behavCam19.avi
# Renaming: 20.avi -> behavCam20.avi
#
# Concatenating session: m388_03072025_14_28_38
# Folder: /Volumes/fsmresfiles/Basic_Sciences/Phys/ContractorLab/Projects/YZ/Miniscope_data/Miniscope_data/Linear_track/2025_07_03/388_14_28_38/My_WebCam
# Number of AVI files: 21
# Output: m388_03072025_14_28_38_concactenatedbehavCam00_behavCam20.mp4
# Width x Height: 640 x 480, FPS: 60.0
# m388_03072025_14_28_38: 100%|███████████████████| 21/21 [00:49<00:00,  2.37s/it]
# Finished: /Volumes/fsmresfiles/Basic_Sciences/Phys/ContractorLab/Projects/YZ/Miniscope_data/Miniscope_data/Linear_track/2025_07_03/388_14_28_38/My_WebCam/m388_03072025_14_28_38_concactenatedbehavCam00_behavCam20.mp4
# Renaming: 0.avi -> behavCam00.avi
# Renaming: 1.avi -> behavCam01.avi
# Renaming: 2.avi -> behavCam02.avi
# Renaming: 3.avi -> behavCam03.avi
# Renaming: 4.avi -> behavCam04.avi
# Renaming: 5.avi -> behavCam05.avi
# Renaming: 6.avi -> behavCam06.avi
# Renaming: 7.avi -> behavCam07.avi
# Renaming: 8.avi -> behavCam08.avi
# Renaming: 9.avi -> behavCam09.avi
# Renaming: 10.avi -> behavCam10.avi
# Renaming: 11.avi -> behavCam11.avi
# Renaming: 12.avi -> behavCam12.avi
# Renaming: 13.avi -> behavCam13.avi
# Renaming: 14.avi -> behavCam14.avi
# Renaming: 15.avi -> behavCam15.avi
# Renaming: 16.avi -> behavCam16.avi
# Renaming: 17.avi -> behavCam17.avi
# Renaming: 18.avi -> behavCam18.avi
# Renaming: 19.avi -> behavCam19.avi
# Renaming: 20.avi -> behavCam20.avi
#
# Concatenating session: m388_04072025_15_43_20
# Folder: /Volumes/fsmresfiles/Basic_Sciences/Phys/ContractorLab/Projects/YZ/Miniscope_data/Miniscope_data/Linear_track/2025_07_04/388_15_43_20/My_WebCam
# Number of AVI files: 21
# Output: m388_04072025_15_43_20_concactenatedbehavCam00_behavCam20.mp4
# Width x Height: 640 x 480, FPS: 60.0
# m388_04072025_15_43_20: 100%|███████████████████| 21/21 [00:48<00:00,  2.29s/it]
# Finished: /Volumes/fsmresfiles/Basic_Sciences/Phys/ContractorLab/Projects/YZ/Miniscope_data/Miniscope_data/Linear_track/2025_07_04/388_15_43_20/My_WebCam/m388_04072025_15_43_20_concactenatedbehavCam00_behavCam20.mp4
# Renaming: 0.avi -> behavCam00.avi
# Renaming: 1.avi -> behavCam01.avi
# Renaming: 2.avi -> behavCam02.avi
# Renaming: 3.avi -> behavCam03.avi
# Renaming: 4.avi -> behavCam04.avi
# Renaming: 5.avi -> behavCam05.avi
# Renaming: 6.avi -> behavCam06.avi
# Renaming: 7.avi -> behavCam07.avi
# Renaming: 8.avi -> behavCam08.avi
# Renaming: 9.avi -> behavCam09.avi
# Renaming: 10.avi -> behavCam10.avi
# Renaming: 11.avi -> behavCam11.avi
# Renaming: 12.avi -> behavCam12.avi
# Renaming: 13.avi -> behavCam13.avi
# Renaming: 14.avi -> behavCam14.avi
# Renaming: 15.avi -> behavCam15.avi
# Renaming: 16.avi -> behavCam16.avi
# Renaming: 17.avi -> behavCam17.avi
# Renaming: 18.avi -> behavCam18.avi
# Renaming: 19.avi -> behavCam19.avi
# Renaming: 20.avi -> behavCam20.avi
#
# Concatenating session: m388_05072025_16_21_10
# Folder: /Volumes/fsmresfiles/Basic_Sciences/Phys/ContractorLab/Projects/YZ/Miniscope_data/Miniscope_data/Linear_track/2025_07_05/388_16_21_10/My_WebCam
# Number of AVI files: 21
# Output: m388_05072025_16_21_10_concactenatedbehavCam00_behavCam20.mp4
# Width x Height: 640 x 480, FPS: 60.0
# m388_05072025_16_21_10: 100%|███████████████████| 21/21 [00:44<00:00,  2.10s/it]
# Finished: /Volumes/fsmresfiles/Basic_Sciences/Phys/ContractorLab/Projects/YZ/Miniscope_data/Miniscope_data/Linear_track/2025_07_05/388_16_21_10/My_WebCam/m388_05072025_16_21_10_concactenatedbehavCam00_behavCam20.mp4
# Renaming: 0.avi -> behavCam00.avi
# Renaming: 1.avi -> behavCam01.avi
# Renaming: 2.avi -> behavCam02.avi
# Renaming: 3.avi -> behavCam03.avi
# Renaming: 4.avi -> behavCam04.avi
# Renaming: 5.avi -> behavCam05.avi
# Renaming: 6.avi -> behavCam06.avi
# Renaming: 7.avi -> behavCam07.avi
# Renaming: 8.avi -> behavCam08.avi
# Renaming: 9.avi -> behavCam09.avi
# Renaming: 10.avi -> behavCam10.avi
# Renaming: 11.avi -> behavCam11.avi
# Renaming: 12.avi -> behavCam12.avi
# Renaming: 13.avi -> behavCam13.avi
# Renaming: 14.avi -> behavCam14.avi
# Renaming: 15.avi -> behavCam15.avi
# Renaming: 16.avi -> behavCam16.avi
# Renaming: 17.avi -> behavCam17.avi
# Renaming: 18.avi -> behavCam18.avi
# Renaming: 19.avi -> behavCam19.avi
# Renaming: 20.avi -> behavCam20.avi
#
# Concatenating session: m388_06072025_14_53_04
# Folder: /Volumes/fsmresfiles/Basic_Sciences/Phys/ContractorLab/Projects/YZ/Miniscope_data/Miniscope_data/Linear_track/2025_07_06/388_14_53_04/My_WebCam
# Number of AVI files: 21
# Output: m388_06072025_14_53_04_concactenatedbehavCam00_behavCam20.mp4
# Width x Height: 640 x 480, FPS: 60.0
# m388_06072025_14_53_04: 100%|███████████████████| 21/21 [00:43<00:00,  2.07s/it]
# Finished: /Volumes/fsmresfiles/Basic_Sciences/Phys/ContractorLab/Projects/YZ/Miniscope_data/Miniscope_data/Linear_track/2025_07_06/388_14_53_04/My_WebCam/m388_06072025_14_53_04_concactenatedbehavCam00_behavCam20.mp4
# Renaming: 0.avi -> behavCam00.avi
# Renaming: 1.avi -> behavCam01.avi
# Renaming: 2.avi -> behavCam02.avi
# Renaming: 3.avi -> behavCam03.avi
# Renaming: 4.avi -> behavCam04.avi
# Renaming: 5.avi -> behavCam05.avi
# Renaming: 6.avi -> behavCam06.avi
# Renaming: 7.avi -> behavCam07.avi
# Renaming: 8.avi -> behavCam08.avi
# Renaming: 9.avi -> behavCam09.avi
# Renaming: 10.avi -> behavCam10.avi
# Renaming: 11.avi -> behavCam11.avi
# Renaming: 12.avi -> behavCam12.avi
# Renaming: 13.avi -> behavCam13.avi
# Renaming: 14.avi -> behavCam14.avi
# Renaming: 15.avi -> behavCam15.avi
# Renaming: 16.avi -> behavCam16.avi
# Renaming: 17.avi -> behavCam17.avi
# Renaming: 18.avi -> behavCam18.avi
# Renaming: 19.avi -> behavCam19.avi
# Renaming: 20.avi -> behavCam20.avi
#
# Concatenating session: m388_07072025_11_39_31
# Folder: /Volumes/fsmresfiles/Basic_Sciences/Phys/ContractorLab/Projects/YZ/Miniscope_data/Miniscope_data/Linear_track/2025_07_07/388_11_39_31/My_WebCam
# Number of AVI files: 21
# Output: m388_07072025_11_39_31_concactenatedbehavCam00_behavCam20.mp4
# Width x Height: 640 x 480, FPS: 60.0
# m388_07072025_11_39_31: 100%|███████████████████| 21/21 [00:44<00:00,  2.10s/it]
# Finished: /Volumes/fsmresfiles/Basic_Sciences/Phys/ContractorLab/Projects/YZ/Miniscope_data/Miniscope_data/Linear_track/2025_07_07/388_11_39_31/My_WebCam/m388_07072025_11_39_31_concactenatedbehavCam00_behavCam20.mp4
# Renaming: 0.avi -> behavCam00.avi
# Renaming: 1.avi -> behavCam01.avi
# Renaming: 2.avi -> behavCam02.avi
# Renaming: 3.avi -> behavCam03.avi
# Renaming: 4.avi -> behavCam04.avi
# Renaming: 5.avi -> behavCam05.avi
# Renaming: 6.avi -> behavCam06.avi
# Renaming: 7.avi -> behavCam07.avi
# Renaming: 8.avi -> behavCam08.avi
# Renaming: 9.avi -> behavCam09.avi
# Renaming: 10.avi -> behavCam10.avi
# Renaming: 11.avi -> behavCam11.avi
# Renaming: 12.avi -> behavCam12.avi
# Renaming: 13.avi -> behavCam13.avi
# Renaming: 14.avi -> behavCam14.avi
# Renaming: 15.avi -> behavCam15.avi
# Renaming: 16.avi -> behavCam16.avi
# Renaming: 17.avi -> behavCam17.avi
# Renaming: 18.avi -> behavCam18.avi
# Renaming: 19.avi -> behavCam19.avi
# Renaming: 20.avi -> behavCam20.avi
#
# Concatenating session: m388_08072025_13_48_35
# Folder: /Volumes/fsmresfiles/Basic_Sciences/Phys/ContractorLab/Projects/YZ/Miniscope_data/Miniscope_data/Linear_track/2025_07_08/388_13_48_35/My_WebCam
# Number of AVI files: 21
# Output: m388_08072025_13_48_35_concactenatedbehavCam00_behavCam20.mp4
# Width x Height: 640 x 480, FPS: 60.0
# m388_08072025_13_48_35: 100%|███████████████████| 21/21 [00:45<00:00,  2.19s/it]
# Finished: /Volumes/fsmresfiles/Basic_Sciences/Phys/ContractorLab/Projects/YZ/Miniscope_data/Miniscope_data/Linear_track/2025_07_08/388_13_48_35/My_WebCam/m388_08072025_13_48_35_concactenatedbehavCam00_behavCam20.mp4
# Renaming: 0.avi -> behavCam00.avi
# Renaming: 1.avi -> behavCam01.avi
# Renaming: 2.avi -> behavCam02.avi
# Renaming: 3.avi -> behavCam03.avi
# Renaming: 4.avi -> behavCam04.avi
# Renaming: 5.avi -> behavCam05.avi
# Renaming: 6.avi -> behavCam06.avi
# Renaming: 7.avi -> behavCam07.avi
# Renaming: 8.avi -> behavCam08.avi
# Renaming: 9.avi -> behavCam09.avi
# Renaming: 10.avi -> behavCam10.avi
# Renaming: 11.avi -> behavCam11.avi
# Renaming: 12.avi -> behavCam12.avi
# Renaming: 13.avi -> behavCam13.avi
# Renaming: 14.avi -> behavCam14.avi
# Renaming: 15.avi -> behavCam15.avi
# Renaming: 16.avi -> behavCam16.avi
# Renaming: 17.avi -> behavCam17.avi
# Renaming: 18.avi -> behavCam18.avi
# Renaming: 19.avi -> behavCam19.avi
# Renaming: 20.avi -> behavCam20.avi
#
# Concatenating session: m388_09072025_11_51_21
# Folder: /Volumes/fsmresfiles/Basic_Sciences/Phys/ContractorLab/Projects/YZ/Miniscope_data/Miniscope_data/Linear_track/2025_07_09/388_11_51_21/My_WebCam
# Number of AVI files: 21
# Output: m388_09072025_11_51_21_concactenatedbehavCam00_behavCam20.mp4
# Width x Height: 640 x 480, FPS: 60.0
# m388_09072025_11_51_21: 100%|███████████████████| 21/21 [00:44<00:00,  2.10s/it]
# Finished: /Volumes/fsmresfiles/Basic_Sciences/Phys/ContractorLab/Projects/YZ/Miniscope_data/Miniscope_data/Linear_track/2025_07_09/388_11_51_21/My_WebCam/m388_09072025_11_51_21_concactenatedbehavCam00_behavCam20.mp4
# Renaming: 0.avi -> behavCam00.avi
# Renaming: 1.avi -> behavCam01.avi
# Renaming: 2.avi -> behavCam02.avi
# Renaming: 3.avi -> behavCam03.avi
# Renaming: 4.avi -> behavCam04.avi
# Renaming: 5.avi -> behavCam05.avi
# Renaming: 6.avi -> behavCam06.avi
# Renaming: 7.avi -> behavCam07.avi
# Renaming: 8.avi -> behavCam08.avi
# Renaming: 9.avi -> behavCam09.avi
# Renaming: 10.avi -> behavCam10.avi
# Renaming: 11.avi -> behavCam11.avi
# Renaming: 12.avi -> behavCam12.avi
# Renaming: 13.avi -> behavCam13.avi
# Renaming: 14.avi -> behavCam14.avi
# Renaming: 15.avi -> behavCam15.avi
# Renaming: 16.avi -> behavCam16.avi
# Renaming: 17.avi -> behavCam17.avi
# Renaming: 18.avi -> behavCam18.avi
# Renaming: 19.avi -> behavCam19.avi
# Renaming: 20.avi -> behavCam20.avi
#
# Concatenating session: m388_10072025_14_00_39
# Folder: /Volumes/fsmresfiles/Basic_Sciences/Phys/ContractorLab/Projects/YZ/Miniscope_data/Miniscope_data/Linear_track/2025_07_10/388_14_00_39/My_WebCam
# Number of AVI files: 21
# Output: m388_10072025_14_00_39_concactenatedbehavCam00_behavCam20.mp4
# Width x Height: 640 x 480, FPS: 60.0
# m388_10072025_14_00_39: 100%|███████████████████| 21/21 [00:44<00:00,  2.12s/it]
# Finished: /Volumes/fsmresfiles/Basic_Sciences/Phys/ContractorLab/Projects/YZ/Miniscope_data/Miniscope_data/Linear_track/2025_07_10/388_14_00_39/My_WebCam/m388_10072025_14_00_39_concactenatedbehavCam00_behavCam20.mp4
# Renaming: 0.avi -> behavCam00.avi
# Renaming: 1.avi -> behavCam01.avi
# Renaming: 2.avi -> behavCam02.avi
# Renaming: 3.avi -> behavCam03.avi
# Renaming: 4.avi -> behavCam04.avi
# Renaming: 5.avi -> behavCam05.avi
# Renaming: 6.avi -> behavCam06.avi
# Renaming: 7.avi -> behavCam07.avi
# Renaming: 8.avi -> behavCam08.avi
# Renaming: 9.avi -> behavCam09.avi
# Renaming: 10.avi -> behavCam10.avi
# Renaming: 11.avi -> behavCam11.avi
# Renaming: 12.avi -> behavCam12.avi
# Renaming: 13.avi -> behavCam13.avi
# Renaming: 14.avi -> behavCam14.avi
# Renaming: 15.avi -> behavCam15.avi
# Renaming: 16.avi -> behavCam16.avi
# Renaming: 17.avi -> behavCam17.avi
# Renaming: 18.avi -> behavCam18.avi
# Renaming: 19.avi -> behavCam19.avi
# Renaming: 20.avi -> behavCam20.avi
#
# Concatenating session: m388_11072025_14_35_14
# Folder: /Volumes/fsmresfiles/Basic_Sciences/Phys/ContractorLab/Projects/YZ/Miniscope_data/Miniscope_data/Linear_track/2025_07_11/388_14_35_14/My_WebCam
# Number of AVI files: 21
# Output: m388_11072025_14_35_14_concactenatedbehavCam00_behavCam20.mp4
# Width x Height: 640 x 480, FPS: 60.0
# m388_11072025_14_35_14: 100%|███████████████████| 21/21 [00:44<00:00,  2.10s/it]
# Finished: /Volumes/fsmresfiles/Basic_Sciences/Phys/ContractorLab/Projects/YZ/Miniscope_data/Miniscope_data/Linear_track/2025_07_11/388_14_35_14/My_WebCam/m388_11072025_14_35_14_concactenatedbehavCam00_behavCam20.mp4
#         date_folder session_folder  \
# 0   2025_07_01_test   388_14_29_09
# 1   2025_07_01_test   388_14_37_41
# 2   2025_07_01_test   388_14_49_45
# 3        2025_07_02   388_14_48_02
# 4        2025_07_03   388_14_28_38
# 5        2025_07_04   388_15_43_20
# 6        2025_07_05   388_16_21_10
# 7        2025_07_06   388_14_53_04
# 8        2025_07_07   388_11_39_31
# 9        2025_07_08   388_13_48_35
# 10       2025_07_09   388_11_51_21
# 11       2025_07_10   388_14_00_39
# 12       2025_07_11   388_14_35_14
#
#                                        My_WebCam_path  \
# 0   /Volumes/fsmresfiles/Basic_Sciences/Phys/Contr...
# 1   /Volumes/fsmresfiles/Basic_Sciences/Phys/Contr...
# 2   /Volumes/fsmresfiles/Basic_Sciences/Phys/Contr...
# 3   /Volumes/fsmresfiles/Basic_Sciences/Phys/Contr...
# 4   /Volumes/fsmresfiles/Basic_Sciences/Phys/Contr...
# 5   /Volumes/fsmresfiles/Basic_Sciences/Phys/Contr...
# 6   /Volumes/fsmresfiles/Basic_Sciences/Phys/Contr...
# 7   /Volumes/fsmresfiles/Basic_Sciences/Phys/Contr...
# 8   /Volumes/fsmresfiles/Basic_Sciences/Phys/Contr...
# 9   /Volumes/fsmresfiles/Basic_Sciences/Phys/Contr...
# 10  /Volumes/fsmresfiles/Basic_Sciences/Phys/Contr...
# 11  /Volumes/fsmresfiles/Basic_Sciences/Phys/Contr...
# 12  /Volumes/fsmresfiles/Basic_Sciences/Phys/Contr...
#
#                                           output_path
# 0   /Volumes/fsmresfiles/Basic_Sciences/Phys/Contr...
# 1   /Volumes/fsmresfiles/Basic_Sciences/Phys/Contr...
# 2   /Volumes/fsmresfiles/Basic_Sciences/Phys/Contr...
# 3   /Volumes/fsmresfiles/Basic_Sciences/Phys/Contr...
# 4   /Volumes/fsmresfiles/Basic_Sciences/Phys/Contr...
# 5   /Volumes/fsmresfiles/Basic_Sciences/Phys/Contr...
# 6   /Volumes/fsmresfiles/Basic_Sciences/Phys/Contr...
# 7   /Volumes/fsmresfiles/Basic_Sciences/Phys/Contr...
# 8   /Volumes/fsmresfiles/Basic_Sciences/Phys/Contr...
# 9   /Volumes/fsmresfiles/Basic_Sciences/Phys/Contr...
# 10  /Volumes/fsmresfiles/Basic_Sciences/Phys/Contr...
# 11  /Volumes/fsmresfiles/Basic_Sciences/Phys/Contr...
# 12  /Volumes/fsmresfiles/Basic_Sciences/Phys/Contr...

# %%
## old code below here 


session_to_concat = 'm994_30122024_18_25_08'

session_path=r'R:\Basic_Sciences\Phys\ContractorLab\Projects\YZ\Miniscope_data\Miniscope_data\Linear_track\2024_12_30\994_18_25_08\My_WebCam'

fList = glob.glob(session_path+'/*.avi')

fList

## justify digits at end of fname with 00s
for video_f in fList:
    fname = video_f.split(os.sep)[-1].strip('.avi')
    reformatted = 'behavCam'+fname.strip('behavCam').zfill(2) +'.avi'
    os.rename(video_f, '/'.join(video_f.split(os.sep)[:-1])+'/'+reformatted)

videos = sorted(glob.glob(session_path+'/*.avi'))

print(videos)


vstoconcat = videos

vcap = cv2.VideoCapture(vstoconcat[0])
width  = vcap.get(cv2.CAP_PROP_FRAME_WIDTH)
height  = vcap.get(cv2.CAP_PROP_FRAME_HEIGHT)
fps = vcap.get(cv2.CAP_PROP_FPS)
# Create a new video
video = cv2.VideoWriter('/'.join(vstoconcat[0].split(os.sep)[:-1])+'/'+ session_to_concat + "_concactenated" + vstoconcat[0].split(os.sep)[-1].strip('.avi') + "_" + vstoconcat[-1].split(os.sep)[-1].strip('.avi') + ".mp4", 
                        cv2.VideoWriter_fourcc(*"MPEG"), fps, (int(width), int(height)))
# Write all the frames sequentially to the new video
for v in tqdm(vstoconcat):
    print(v)
    curr_v = cv2.VideoCapture(v)
    while curr_v.isOpened():
        r, frame = curr_v.read()    # Get return value and curr frame of curr video
        if not r:
            break
        video.write(frame)          # Write the frame
video.release()

# %%
## renaming timestampfiles from shell script
#!bash copyAndRenameTimeStampFiles.sh

# %%
# to move all final concactenated file names
#!base="/Volumes/fsmresfiles/Basic_Sciences/Phys/ContractorLab/Projects/YZ/Miniscope_data/Miniscope_data/Linear_track"; mouse_num="328"; dest="$base/BehavCamConcactenated_${mouse_num}"; mkdir -p "$dest"; find "$base" -type f -path "*/${mouse_num}_*/My_WebCam/*concactenatedbehav*.mp4" -exec cp -n {} "$dest"/ \;
