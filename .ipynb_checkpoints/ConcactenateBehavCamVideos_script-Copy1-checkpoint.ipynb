# %%
import glob
import os 
import cv2
from tqdm import tqdm

# %%
session_to_concat = 'm328_run4_20250702_behavCamFiles'

session_path='/Volumes/fsmresfiles/Basic_Sciences/Phys/ContractorLab/Projects/Common Files/JJM_YZ_CaImaging/2025.7/388_run4_20250702_behavCamFiles'

fList = glob.glob(session_path+'/*.avi')

fList

## justify digits at end of fname with 00s
for video_f in fList:
    fname = video_f.split(os.sep)[-1].strip('.avi')
    reformatted = 'behavCam'+fname.strip('behavCam').zfill(2) +'.avi'
    os.rename(video_f, '/'.join(video_f.split(os.sep)[:-1])+'/'+reformatted)

videos = sorted(glob.glob(session_path+'/*.avi'))

print(videos)

vstoconcat = videos

vcap = cv2.VideoCapture(vstoconcat[0])
width  = vcap.get(cv2.CAP_PROP_FRAME_WIDTH)
height  = vcap.get(cv2.CAP_PROP_FRAME_HEIGHT)
fps = vcap.get(cv2.CAP_PROP_FPS)
# Create a new video
video = cv2.VideoWriter('/'.join(vstoconcat[0].split(os.sep)[:-1])+'/'+ session_to_concat + "_concactenated" + vstoconcat[0].split(os.sep)[-1].strip('.avi') + "_" + vstoconcat[-1].split(os.sep)[-1].strip('.avi') + ".mp4", 
                        cv2.VideoWriter_fourcc(*"MPEG"), fps, (int(width), int(height)))
# Write all the frames sequentially to the new video
for v in tqdm(vstoconcat):
    print(v)
    curr_v = cv2.VideoCapture(v)
    while curr_v.isOpened():
        r, frame = curr_v.read()    # Get return value and curr frame of curr video
        if not r:
            break
        video.write(frame)          # Write the frame
video.release()
# Out:
# ['/Volumes/fsmresfiles/Basic_Sciences/Phys/ContractorLab/Projects/Common Files/JJM_YZ_CaImaging/2025.7/388_run4_20250702_behavCamFiles/behavCam00.avi', '/Volumes/fsmresfiles/Basic_Sciences/Phys/ContractorLab/Projects/Common Files/JJM_YZ_CaImaging/2025.7/388_run4_20250702_behavCamFiles/behavCam01.avi', '/Volumes/fsmresfiles/Basic_Sciences/Phys/ContractorLab/Projects/Common Files/JJM_YZ_CaImaging/2025.7/388_run4_20250702_behavCamFiles/behavCam02.avi', '/Volumes/fsmresfiles/Basic_Sciences/Phys/ContractorLab/Projects/Common Files/JJM_YZ_CaImaging/2025.7/388_run4_20250702_behavCamFiles/behavCam03.avi', '/Volumes/fsmresfiles/Basic_Sciences/Phys/ContractorLab/Projects/Common Files/JJM_YZ_CaImaging/2025.7/388_run4_20250702_behavCamFiles/behavCam04.avi', '/Volumes/fsmresfiles/Basic_Sciences/Phys/ContractorLab/Projects/Common Files/JJM_YZ_CaImaging/2025.7/388_run4_20250702_behavCamFiles/behavCam05.avi', '/Volumes/fsmresfiles/Basic_Sciences/Phys/ContractorLab/Projects/Common Files/JJM_YZ_CaImaging/2025.7/388_run4_20250702_behavCamFiles/behavCam06.avi', '/Volumes/fsmresfiles/Basic_Sciences/Phys/ContractorLab/Projects/Common Files/JJM_YZ_CaImaging/2025.7/388_run4_20250702_behavCamFiles/behavCam07.avi', '/Volumes/fsmresfiles/Basic_Sciences/Phys/ContractorLab/Projects/Common Files/JJM_YZ_CaImaging/2025.7/388_run4_20250702_behavCamFiles/behavCam08.avi', '/Volumes/fsmresfiles/Basic_Sciences/Phys/ContractorLab/Projects/Common Files/JJM_YZ_CaImaging/2025.7/388_run4_20250702_behavCamFiles/behavCam09.avi', '/Volumes/fsmresfiles/Basic_Sciences/Phys/ContractorLab/Projects/Common Files/JJM_YZ_CaImaging/2025.7/388_run4_20250702_behavCamFiles/behavCam10.avi', '/Volumes/fsmresfiles/Basic_Sciences/Phys/ContractorLab/Projects/Common Files/JJM_YZ_CaImaging/2025.7/388_run4_20250702_behavCamFiles/behavCam11.avi', '/Volumes/fsmresfiles/Basic_Sciences/Phys/ContractorLab/Projects/Common Files/JJM_YZ_CaImaging/2025.7/388_run4_20250702_behavCamFiles/behavCam12.avi', '/Volumes/fsmresfiles/Basic_Sciences/Phys/ContractorLab/Projects/Common Files/JJM_YZ_CaImaging/2025.7/388_run4_20250702_behavCamFiles/behavCam13.avi', '/Volumes/fsmresfiles/Basic_Sciences/Phys/ContractorLab/Projects/Common Files/JJM_YZ_CaImaging/2025.7/388_run4_20250702_behavCamFiles/behavCam14.avi', '/Volumes/fsmresfiles/Basic_Sciences/Phys/ContractorLab/Projects/Common Files/JJM_YZ_CaImaging/2025.7/388_run4_20250702_behavCamFiles/behavCam15.avi', '/Volumes/fsmresfiles/Basic_Sciences/Phys/ContractorLab/Projects/Common Files/JJM_YZ_CaImaging/2025.7/388_run4_20250702_behavCamFiles/behavCam16.avi', '/Volumes/fsmresfiles/Basic_Sciences/Phys/ContractorLab/Projects/Common Files/JJM_YZ_CaImaging/2025.7/388_run4_20250702_behavCamFiles/behavCam17.avi', '/Volumes/fsmresfiles/Basic_Sciences/Phys/ContractorLab/Projects/Common Files/JJM_YZ_CaImaging/2025.7/388_run4_20250702_behavCamFiles/behavCam18.avi', '/Volumes/fsmresfiles/Basic_Sciences/Phys/ContractorLab/Projects/Common Files/JJM_YZ_CaImaging/2025.7/388_run4_20250702_behavCamFiles/behavCam19.avi', '/Volumes/fsmresfiles/Basic_Sciences/Phys/ContractorLab/Projects/Common Files/JJM_YZ_CaImaging/2025.7/388_run4_20250702_behavCamFiles/behavCam20.avi']
# OpenCV: FFMPEG: tag 0x4745504d/'MPEG' is not supported with codec id 2 and format 'mp4 / MP4 (MPEG-4 Part 14)'
# OpenCV: FFMPEG: fallback to use tag 0x7634706d/'mp4v'
#   0%|                                                                              | 0/21 [00:00<?, ?it/s]
# /Volumes/fsmresfiles/Basic_Sciences/Phys/ContractorLab/Projects/Common Files/JJM_YZ_CaImaging/2025.7/388_run4_20250702_behavCamFiles/behavCam00.avi
#   5%|███▎                                                                  | 1/21 [00:03<01:13,  3.66s/it]
# /Volumes/fsmresfiles/Basic_Sciences/Phys/ContractorLab/Projects/Common Files/JJM_YZ_CaImaging/2025.7/388_run4_20250702_behavCamFiles/behavCam01.avi
#  10%|██████▋                                                               | 2/21 [00:07<01:07,  3.55s/it]
# /Volumes/fsmresfiles/Basic_Sciences/Phys/ContractorLab/Projects/Common Files/JJM_YZ_CaImaging/2025.7/388_run4_20250702_behavCamFiles/behavCam02.avi
#  14%|██████████                                                            | 3/21 [00:09<00:57,  3.18s/it]
# /Volumes/fsmresfiles/Basic_Sciences/Phys/ContractorLab/Projects/Common Files/JJM_YZ_CaImaging/2025.7/388_run4_20250702_behavCamFiles/behavCam03.avi
#  19%|█████████████▎                                                        | 4/21 [00:12<00:52,  3.07s/it]
# /Volumes/fsmresfiles/Basic_Sciences/Phys/ContractorLab/Projects/Common Files/JJM_YZ_CaImaging/2025.7/388_run4_20250702_behavCamFiles/behavCam04.avi
#  24%|████████████████▋                                                     | 5/21 [00:15<00:47,  2.97s/it]
# /Volumes/fsmresfiles/Basic_Sciences/Phys/ContractorLab/Projects/Common Files/JJM_YZ_CaImaging/2025.7/388_run4_20250702_behavCamFiles/behavCam05.avi
#  29%|████████████████████                                                  | 6/21 [00:18<00:44,  2.99s/it]
# /Volumes/fsmresfiles/Basic_Sciences/Phys/ContractorLab/Projects/Common Files/JJM_YZ_CaImaging/2025.7/388_run4_20250702_behavCamFiles/behavCam06.avi
#  33%|███████████████████████▎                                              | 7/21 [00:21<00:43,  3.12s/it]
# /Volumes/fsmresfiles/Basic_Sciences/Phys/ContractorLab/Projects/Common Files/JJM_YZ_CaImaging/2025.7/388_run4_20250702_behavCamFiles/behavCam07.avi
#  38%|██████████████████████████▋                                           | 8/21 [00:25<00:40,  3.13s/it]
# /Volumes/fsmresfiles/Basic_Sciences/Phys/ContractorLab/Projects/Common Files/JJM_YZ_CaImaging/2025.7/388_run4_20250702_behavCamFiles/behavCam08.avi
#  43%|██████████████████████████████                                        | 9/21 [00:28<00:37,  3.14s/it]
# /Volumes/fsmresfiles/Basic_Sciences/Phys/ContractorLab/Projects/Common Files/JJM_YZ_CaImaging/2025.7/388_run4_20250702_behavCamFiles/behavCam09.avi
#  48%|████████████████████████████████▊                                    | 10/21 [00:31<00:35,  3.23s/it]
# /Volumes/fsmresfiles/Basic_Sciences/Phys/ContractorLab/Projects/Common Files/JJM_YZ_CaImaging/2025.7/388_run4_20250702_behavCamFiles/behavCam10.avi
#  52%|████████████████████████████████████▏                                | 11/21 [00:34<00:31,  3.13s/it]
# /Volumes/fsmresfiles/Basic_Sciences/Phys/ContractorLab/Projects/Common Files/JJM_YZ_CaImaging/2025.7/388_run4_20250702_behavCamFiles/behavCam11.avi
#  57%|███████████████████████████████████████▍                             | 12/21 [00:40<00:34,  3.82s/it]
# /Volumes/fsmresfiles/Basic_Sciences/Phys/ContractorLab/Projects/Common Files/JJM_YZ_CaImaging/2025.7/388_run4_20250702_behavCamFiles/behavCam12.avi
#  62%|██████████████████████████████████████████▋                          | 13/21 [00:42<00:28,  3.52s/it]
# /Volumes/fsmresfiles/Basic_Sciences/Phys/ContractorLab/Projects/Common Files/JJM_YZ_CaImaging/2025.7/388_run4_20250702_behavCamFiles/behavCam13.avi
#  67%|██████████████████████████████████████████████                       | 14/21 [00:45<00:23,  3.33s/it]
# /Volumes/fsmresfiles/Basic_Sciences/Phys/ContractorLab/Projects/Common Files/JJM_YZ_CaImaging/2025.7/388_run4_20250702_behavCamFiles/behavCam14.avi
#  71%|█████████████████████████████████████████████████▎                   | 15/21 [00:49<00:19,  3.33s/it]
# /Volumes/fsmresfiles/Basic_Sciences/Phys/ContractorLab/Projects/Common Files/JJM_YZ_CaImaging/2025.7/388_run4_20250702_behavCamFiles/behavCam15.avi
#  76%|████████████████████████████████████████████████████▌                | 16/21 [00:52<00:16,  3.40s/it]
# /Volumes/fsmresfiles/Basic_Sciences/Phys/ContractorLab/Projects/Common Files/JJM_YZ_CaImaging/2025.7/388_run4_20250702_behavCamFiles/behavCam16.avi
#  81%|███████████████████████████████████████████████████████▊             | 17/21 [00:56<00:13,  3.44s/it]
# /Volumes/fsmresfiles/Basic_Sciences/Phys/ContractorLab/Projects/Common Files/JJM_YZ_CaImaging/2025.7/388_run4_20250702_behavCamFiles/behavCam17.avi
#  86%|███████████████████████████████████████████████████████████▏         | 18/21 [00:59<00:09,  3.32s/it]
# /Volumes/fsmresfiles/Basic_Sciences/Phys/ContractorLab/Projects/Common Files/JJM_YZ_CaImaging/2025.7/388_run4_20250702_behavCamFiles/behavCam18.avi
#  90%|██████████████████████████████████████████████████████████████▍      | 19/21 [01:02<00:06,  3.24s/it]
# /Volumes/fsmresfiles/Basic_Sciences/Phys/ContractorLab/Projects/Common Files/JJM_YZ_CaImaging/2025.7/388_run4_20250702_behavCamFiles/behavCam19.avi
#  95%|█████████████████████████████████████████████████████████████████▋   | 20/21 [01:05<00:03,  3.25s/it]
# /Volumes/fsmresfiles/Basic_Sciences/Phys/ContractorLab/Projects/Common Files/JJM_YZ_CaImaging/2025.7/388_run4_20250702_behavCamFiles/behavCam20.avi
# 100%|█████████████████████████████████████████████████████████████████████| 21/21 [01:07<00:00,  3.21s/it]
